# %% [markdown]
# ### Cost model benchmarking - case study #1
#
# Loosely based on Dudgeon Wind Farm (400 MW, 8MW turbines)
#
# National Renewable Energy Lab
#
# Matt Shields, Jake Nunemaker
#
# Updated: 2/17/2020

# %%
import os
import sys
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as plt_dates

import ORBIT
print(f"Using ORBIT version {ORBIT.__version__}.")
from ORBIT import ProjectManager


usd_to_euro = 0.92
# Out:
# Using ORBIT version 0+unknown.

# %% [markdown]
# #### Weather File

# %%
filepath = os.path.join('library', 'weather', 'dudgeon_wave_100m_wind.csv')
weather = pd.read_csv(filepath).set_index(keys='datetime')
weather.describe()
# Out:
#           windspeed    waveheight
# count  20616.000000  20616.000000
# mean       9.138532      1.183350
# std        4.249767      0.667603
# min        0.121744      0.170372
# 25%        5.980583      0.698537
# 50%        8.916669      1.027665
# 75%       11.878717      1.507961
# max       25.680700      5.773216

# %% [markdown]
# #### ORBIT Configuration

# %%
phases = [
    # Substructures
    'MonopileInstallation',
#     'ScourProtectionDesign',
#     'ScourProtectionInstallation',
    
    # Turbines
    'TurbineInstallation',
    
#     # Electrical
    'ArraySystemDesign',
    'ArrayCableInstallation',
    'ExportSystemDesign',
    'ExportCableInstallation',
#     'OffshoreSubstationInstallation'
]

required_config = ProjectManager.compile_input_dict(phases)
# required_config

# %%
config = {
    # Substations
#     "num_substations": 1,
    
    # Vessels
#     'scour_protection_install_vessel': 'ExampleScour',
#     'trench_dig_vessel': 'StematSpirit',
#     'array_cable_lay_vessel': 'cable_lay_vessel',
#     'export_cable_lay_vessel': 'StematSpirit',
#     "oss_install_vessel": "OlegStrashnov",  # Actually vessel from SPT Offshore
    
    # Site/plant
    'site': {
        'depth': 22.5,
        'distance': 124,
        'distance_to_landfall': 42,
        'distance_to_beach': 0,
        'distance_to_interconnection': 3,
        'mean_windspeed': 9.13
    },
    
    'plant': {
        'layout': 'grid',
        'num_turbines': 50,
        'row_spacing': 7,
        'turbine_spacing': 9,
        'substation_distance': 1
    },
    
    'port': {
        'num_cranes': 1,
        'monthly_rate': 2000000,
        "name": "Green Port"
    },
    
    # Turbine + components
    'turbine': '8MW_generic',

    # Substructure components
    'substructure': {'diameter': 7.2},
    'monopile': {
        'type': 'Monopile',
        'length': 69,
        'diameter': 7.2,
        'deck_space': 496.8,
        'mass': 800,
        'monopile_steel_cost' : 2000 / usd_to_euro,
    },
    
    'transition_piece': {
        'type': 'Transition Piece',
        'deck_space': 100,
        'mass': 400,
        'transition_piece_steel_cost' : 2000 / usd_to_euro,
    },
    
#     'scour_protection_design': {
#         'cost_per_tonne': 40,
#     },
    
    # Electrical
    'array_system_design': {
        'cables': 'XLPE_630mm_66kV'
    },
    
    'array_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system_design': {
        'cables': 'XLPE_1000mm_220kV',
        'percent_added_length': 0
    },
    
#     "offshore_substation_topside": {
#         "type": "Topside",
#         "deck_space": 200,
#         "weight": 2000,
#     },
#     "offshore_substation_substructure": {
#         "type": "Monopile",
#         "deck_space": 500,
#         "weight": 1850,
#         "length": 69,  # Assumed to be the same as monopile length
#     },


    # Phase specific configurations
    'MonopileInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine',  
        
    },
    
    'TurbineInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine'
    },
    
    'ArrayCableInstallation': {
        'array_cable_install_vessel' : 'cable_lay_vessel'
    }, 
    
    'ExportCableInstallation': {
        'export_cable_install_vessel' : 'cable_lay_vessel'
    },
    
#     'OffshoreSubstationInstallation': {
#         "num_feeders": 1,
#         "feeder": "seajacks_scylla",
#     },    
    
    # Phases
    'design_phases': [
#         "MonopileDesign",
#         'ScourProtectionDesign',
        'ArraySystemDesign',
        'ExportSystemDesign',
#         'OffshoreSubstationDesign'
    ],
    
    'install_phases': {
        'MonopileInstallation': '07/01/2016',         # Updated dates 
#         'ScourProtectionInstallation': '09/01/2016',  # Placed at the end of the monopile installation
        'TurbineInstallation': '07/01/2016',
        'ArrayCableInstallation': '07/01/2016',
        'ExportCableInstallation': '07/01/2016',
#         'OffshoreSubstationInstallation': '08/01/2016'
    }
}

# %%
path = os.path.join(os.getcwd(), "library")
project = ProjectManager(config, weather=weather, library_path=path)
# Out:
# ORBIT library intialized at 'C:\Users\mshields\Documents\Analysis Tools\NREL\ORBIT\Analysis\library'

# %%
project.run_project()

# %% [markdown]
# # Results
#
# ### Turbine installation

# %%
# Trip data
project._phases['TurbineInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=1506, deck_space=1942, items={TowerSection: 4, Nacelle: 2, Blade: 6})]

# %%
# Installation costs 
turb_time = np.round(project._phases['TurbineInstallation'].total_phase_time * (1/24) ,1 ) # Convert hours to days
turb_cost = np.round(project._phases['TurbineInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Turbine install time: ', turb_time, 'days')
print('Turbine install cost: ', turb_cost, 'M Euros')
# Out:
# Turbine install time:  149.1 days
# Turbine install cost:  38.8 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='TurbineInstallation']
# Out:
#                      action agent  cable_lay_speed           cost  \
# 1                  Mobilize  WTIV              NaN  322500.000000
# 5      Fasten Tower Section  WTIV              NaN   35833.333333
# 11     Fasten Tower Section  WTIV              NaN   35833.333333
# 13           Fasten Nacelle  WTIV              NaN   35833.333333
# 16             Fasten Blade  WTIV              NaN   13437.500000
# 18             Fasten Blade  WTIV              NaN   13437.500000
# 20             Fasten Blade  WTIV              NaN   13437.500000
# 24     Fasten Tower Section  WTIV              NaN   35833.333333
# 26     Fasten Tower Section  WTIV              NaN   35833.333333
# 29           Fasten Nacelle  WTIV              NaN   35833.333333
# 30             Fasten Blade  WTIV              NaN   13437.500000
# 31             Fasten Blade  WTIV              NaN   13437.500000
# 33             Fasten Blade  WTIV              NaN   13437.500000
# 34     Fasten Tower Section  WTIV              NaN   35833.333333
# 38     Fasten Tower Section  WTIV              NaN   35833.333333
# 40           Fasten Nacelle  WTIV              NaN   35833.333333
# 41             Fasten Blade  WTIV              NaN   13437.500000
# 42             Fasten Blade  WTIV              NaN   13437.500000
# 44             Fasten Blade  WTIV              NaN   13437.500000
# 48     Fasten Tower Section  WTIV              NaN   35833.333333
# 49     Fasten Tower Section  WTIV              NaN   35833.333333
# 52           Fasten Nacelle  WTIV              NaN   35833.333333
# 53             Fasten Blade  WTIV              NaN   13437.500000
# 56             Fasten Blade  WTIV              NaN   13437.500000
# 57             Fasten Blade  WTIV              NaN   13437.500000
# 60                  Transit  WTIV              NaN   74055.555556
# 62          Position Onsite  WTIV              NaN   17916.666667
# 63                   Jackup  WTIV              NaN   12131.076389
# 66    Release Tower Section  WTIV              NaN   26875.000000
# 67       Lift Tower Section  WTIV              NaN     118.200231
# ...                     ...   ...              ...            ...
# 2724          Release Blade  WTIV              NaN    8958.333333
# 2725             Lift Blade  WTIV              NaN     234.326775
# 2726           Attach Blade  WTIV              NaN   31354.166667
# 2727          Release Blade  WTIV              NaN    8958.333333
# 2728             Lift Blade  WTIV              NaN     234.326775
# 2729           Attach Blade  WTIV              NaN   31354.166667
# 2730               Jackdown  WTIV              NaN   12131.076389
# 2731        Position Onsite  WTIV              NaN   17916.666667
# 2732                 Jackup  WTIV              NaN   12131.076389
# 2733  Release Tower Section  WTIV              NaN   26875.000000
# 2734     Lift Tower Section  WTIV              NaN     118.200231
# 2735   Attach Tower Section  WTIV              NaN   53750.000000
# 2736  Release Tower Section  WTIV              NaN   26875.000000
# 2737     Lift Tower Section  WTIV              NaN     236.400463
# 2738   Attach Tower Section  WTIV              NaN   53750.000000
# 2739        Release Nacelle  WTIV              NaN   26875.000000
# 2740                Reequip  WTIV              NaN    8958.333333
# 2741           Lift Nacelle  WTIV              NaN     234.326775
# 2742         Attach Nacelle  WTIV              NaN   53750.000000
# 2743                Reequip  WTIV              NaN    8958.333333
# 2744          Release Blade  WTIV              NaN    8958.333333
# 2745             Lift Blade  WTIV              NaN     234.326775
# 2746           Attach Blade  WTIV              NaN   31354.166667
# 2747          Release Blade  WTIV              NaN    8958.333333
# 2748             Lift Blade  WTIV              NaN     234.326775
# 2749           Attach Blade  WTIV              NaN   31354.166667
# 2750          Release Blade  WTIV              NaN    8958.333333
# 2751             Lift Blade  WTIV              NaN     234.326775
# 2752           Attach Blade  WTIV              NaN   31354.166667
# 2753               Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier   duration  hub_height   level location  max_waveheight  \
# 1                 0.5  72.000000         NaN  ACTION      NaN             NaN
# 5                 NaN   4.000000       113.0  ACTION      NaN             NaN
# 11                NaN   4.000000       113.0  ACTION      NaN             NaN
# 13                NaN   4.000000       113.0  ACTION      NaN             NaN
# 16                NaN   1.500000       113.0  ACTION      NaN             NaN
# 18                NaN   1.500000       113.0  ACTION      NaN             NaN
# 20                NaN   1.500000       113.0  ACTION      NaN             NaN
# 24                NaN   4.000000       113.0  ACTION      NaN             NaN
# 26                NaN   4.000000       113.0  ACTION      NaN             NaN
# 29                NaN   4.000000       113.0  ACTION      NaN             NaN
# 30                NaN   1.500000       113.0  ACTION      NaN             NaN
# 31                NaN   1.500000       113.0  ACTION      NaN             NaN
# 33                NaN   1.500000       113.0  ACTION      NaN             NaN
# 34                NaN   4.000000       113.0  ACTION      NaN             NaN
# 38                NaN   4.000000       113.0  ACTION      NaN             NaN
# 40                NaN   4.000000       113.0  ACTION      NaN             NaN
# 41                NaN   1.500000       113.0  ACTION      NaN             NaN
# 42                NaN   1.500000       113.0  ACTION      NaN             NaN
# 44                NaN   1.500000       113.0  ACTION      NaN             NaN
# 48                NaN   4.000000       113.0  ACTION      NaN             NaN
# 49                NaN   4.000000       113.0  ACTION      NaN             NaN
# 52                NaN   4.000000       113.0  ACTION      NaN             NaN
# 53                NaN   1.500000       113.0  ACTION      NaN             NaN
# 56                NaN   1.500000       113.0  ACTION      NaN             NaN
# 57                NaN   1.500000       113.0  ACTION      NaN             NaN
# 60                NaN   8.266667         NaN  ACTION      NaN             NaN
# 62                NaN   2.000000         NaN  ACTION      NaN             NaN
# 63                NaN   1.354167       113.0  ACTION      NaN             NaN
# 66                NaN   3.000000         NaN  ACTION      NaN             NaN
# 67                NaN   0.013194       113.0  ACTION      NaN             NaN
# ...               ...        ...         ...     ...      ...             ...
# 2724              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2725              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2726              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2727              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2728              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2729              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2730              NaN   1.354167         NaN  ACTION      NaN             NaN
# 2731              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2732              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2733              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2734              NaN   0.013194       113.0  ACTION      NaN             NaN
# 2735              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2736              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2737              NaN   0.026389       113.0  ACTION      NaN             NaN
# 2738              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2739              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2740              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2741              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2742              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2743              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2744              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2745              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2746              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2747              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2748              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2749              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2750              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2751              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2752              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2753              NaN   1.354167         NaN  ACTION      NaN             NaN
#
#       max_windspeed                phase           phase_name  site_depth  \
# 1               NaN  TurbineInstallation                  NaN         NaN
# 5               NaN  TurbineInstallation  TurbineInstallation        22.5
# 11              NaN  TurbineInstallation  TurbineInstallation        22.5
# 13              NaN  TurbineInstallation  TurbineInstallation        22.5
# 16              NaN  TurbineInstallation  TurbineInstallation        22.5
# 18              NaN  TurbineInstallation  TurbineInstallation        22.5
# 20              NaN  TurbineInstallation  TurbineInstallation        22.5
# 24              NaN  TurbineInstallation  TurbineInstallation        22.5
# 26              NaN  TurbineInstallation  TurbineInstallation        22.5
# 29              NaN  TurbineInstallation  TurbineInstallation        22.5
# 30              NaN  TurbineInstallation  TurbineInstallation        22.5
# 31              NaN  TurbineInstallation  TurbineInstallation        22.5
# 33              NaN  TurbineInstallation  TurbineInstallation        22.5
# 34              NaN  TurbineInstallation  TurbineInstallation        22.5
# 38              NaN  TurbineInstallation  TurbineInstallation        22.5
# 40              NaN  TurbineInstallation  TurbineInstallation        22.5
# 41              NaN  TurbineInstallation  TurbineInstallation        22.5
# 42              NaN  TurbineInstallation  TurbineInstallation        22.5
# 44              NaN  TurbineInstallation  TurbineInstallation        22.5
# 48              NaN  TurbineInstallation  TurbineInstallation        22.5
# 49              NaN  TurbineInstallation  TurbineInstallation        22.5
# 52              NaN  TurbineInstallation  TurbineInstallation        22.5
# 53              NaN  TurbineInstallation  TurbineInstallation        22.5
# 56              NaN  TurbineInstallation  TurbineInstallation        22.5
# 57              NaN  TurbineInstallation  TurbineInstallation        22.5
# 60              NaN  TurbineInstallation                  NaN         NaN
# 62              NaN  TurbineInstallation                  NaN         NaN
# 63              NaN  TurbineInstallation  TurbineInstallation        22.5
# 66              NaN  TurbineInstallation                  NaN         NaN
# 67              NaN  TurbineInstallation  TurbineInstallation        22.5
# ...             ...                  ...                  ...         ...
# 2724            NaN  TurbineInstallation                  NaN         NaN
# 2725            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2726            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2727            NaN  TurbineInstallation                  NaN         NaN
# 2728            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2729            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2730            NaN  TurbineInstallation                  NaN         NaN
# 2731            NaN  TurbineInstallation                  NaN         NaN
# 2732            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2733            NaN  TurbineInstallation                  NaN         NaN
# 2734            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2735            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2736            NaN  TurbineInstallation                  NaN         NaN
# 2737            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2738            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2739            NaN  TurbineInstallation                  NaN         NaN
# 2740            NaN  TurbineInstallation                  NaN         NaN
# 2741            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2742            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2743            NaN  TurbineInstallation                  NaN         NaN
# 2744            NaN  TurbineInstallation                  NaN         NaN
# 2745            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2746            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2747            NaN  TurbineInstallation                  NaN         NaN
# 2748            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2749            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2750            NaN  TurbineInstallation                  NaN         NaN
# 2751            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2752            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2753            NaN  TurbineInstallation                  NaN         NaN
#
#              time  transit_speed
# 1        0.000000            NaN
# 5        4.000000            NaN
# 11       8.000000            NaN
# 13      12.000000            NaN
# 16      13.500000            NaN
# 18      15.000000            NaN
# 20      16.500000            NaN
# 24      20.500000            NaN
# 26      24.500000            NaN
# 29      28.500000            NaN
# 30      30.000000            NaN
# 31      31.500000            NaN
# 33      33.000000            NaN
# 34      37.000000            NaN
# 38      41.000000            NaN
# 40      45.000000            NaN
# 41      46.500000            NaN
# 42      48.000000            NaN
# 44      49.500000            NaN
# 48      53.500000            NaN
# 49      57.500000            NaN
# 52      61.500000            NaN
# 53      63.000000            NaN
# 56      64.500000            NaN
# 57      66.000000            NaN
# 60      74.266667            NaN
# 62      76.266667            NaN
# 63      77.620833            NaN
# 66      80.620833            NaN
# 67      80.634028            NaN
# ...           ...            ...
# 2724  3520.534954            NaN
# 2725  3520.561111            NaN
# 2726  3524.061111            NaN
# 2727  3525.061111            NaN
# 2728  3525.087269            NaN
# 2729  3528.587269            NaN
# 2730  3529.941435            NaN
# 2731  3531.941435            NaN
# 2732  3533.295602            NaN
# 2733  3536.295602            NaN
# 2734  3536.308796            NaN
# 2735  3542.308796            NaN
# 2736  3545.308796            NaN
# 2737  3545.335185            NaN
# 2738  3551.335185            NaN
# 2739  3554.335185            NaN
# 2740  3555.335185            NaN
# 2741  3555.361343            NaN
# 2742  3561.361343            NaN
# 2743  3562.361343            NaN
# 2744  3563.361343            NaN
# 2745  3563.387500            NaN
# 2746  3566.887500            NaN
# 2747  3567.887500            NaN
# 2748  3567.913657            NaN
# 2749  3571.413657            NaN
# 2750  3572.413657            NaN
# 2751  3572.439815            NaN
# 2752  3575.939815            NaN
# 2753  3577.293981            NaN
#
# [1493 rows x 16 columns]

# %% [markdown]
# ### Monopile design and installation

# %%
# Trip data
project._phases['MonopileInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=2400, deck_space=1193.6, items={Monopile: 2, TransitionPiece: 2})]

# %%
# Installation and capital costs 
mono_time = np.round(project._phases['MonopileInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
mono_install_cost = np.round(project._phases['MonopileInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
mono_capital_cost = np.round(((config['monopile']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['monopile']['monopile_steel_cost']) +
                     (config['transition_piece']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['transition_piece']['transition_piece_steel_cost']))* 1e-6 * usd_to_euro , 1)

print('Monopile install time: ', mono_time, 'days')
print('Monopile install cost: ', mono_install_cost, 'M Euros')
print('Monopile capital cost: ', mono_capital_cost, 'M Euros')
print('Monopile total cost: ', mono_capital_cost + mono_install_cost, 'M Euros')
# Out:
# Monopile install time:  87.4 days
# Monopile install cost:  22.9 M Euros
# Monopile capital cost:  120.0 M Euros
# Monopile total cost:  142.9 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='MonopileInstallation']
# Out:
#                         action agent  cable_lay_speed           cost  \
# 0                     Mobilize  WTIV              NaN  322500.000000
# 12             Fasten Monopile  WTIV              NaN  107500.000000
# 23     Fasten Transition Piece  WTIV              NaN   71666.666667
# 32             Fasten Monopile  WTIV              NaN  107500.000000
# 37     Fasten Transition Piece  WTIV              NaN   71666.666667
# 46             Fasten Monopile  WTIV              NaN  107500.000000
# 51     Fasten Transition Piece  WTIV              NaN   71666.666667
# 58             Fasten Monopile  WTIV              NaN  107500.000000
# 64     Fasten Transition Piece  WTIV              NaN   71666.666667
# 74             Fasten Monopile  WTIV              NaN  107500.000000
# 81     Fasten Transition Piece  WTIV              NaN   71666.666667
# 90             Fasten Monopile  WTIV              NaN  107500.000000
# 98     Fasten Transition Piece  WTIV              NaN   71666.666667
# 108                    Transit  WTIV              NaN   74055.555556
# 109            Position Onsite  WTIV              NaN   17916.666667
# 110                     Jackup  WTIV              NaN   12131.076389
# 112                  RovSurvey  WTIV              NaN    8958.333333
# 115           Release Monopile  WTIV              NaN   26875.000000
# 116             Upend Monopile  WTIV              NaN     143.084491
# 117             Lower Monopile  WTIV              NaN       0.018001
# 118              Crane Reequip  WTIV              NaN    8958.333333
# 121             Drive Monopile  WTIV              NaN   13437.500000
# 124   Release Transition Piece  WTIV              NaN   17916.666667
# 125              Crane Reequip  WTIV              NaN    8958.333333
# 126                   Lower TP  WTIV              NaN      20.736883
# 128                    Bolt TP  WTIV              NaN   35833.333333
# 131                   Jackdown  WTIV              NaN   12131.076389
# 134            Position Onsite  WTIV              NaN   17916.666667
# 135                     Jackup  WTIV              NaN   12131.076389
# 137                  RovSurvey  WTIV              NaN    8958.333333
# ...                        ...   ...              ...            ...
# 2092   Fasten Transition Piece  WTIV              NaN   71666.666667
# 2096                   Transit  WTIV              NaN   74055.555556
# 2097           Position Onsite  WTIV              NaN   17916.666667
# 2100                    Jackup  WTIV              NaN   12131.076389
# 2101                 RovSurvey  WTIV              NaN    8958.333333
# 2102          Release Monopile  WTIV              NaN   26875.000000
# 2103                     Delay  WTIV              NaN   89583.333333
# 2104            Upend Monopile  WTIV              NaN     143.084491
# 2105            Lower Monopile  WTIV              NaN       0.018001
# 2106             Crane Reequip  WTIV              NaN    8958.333333
# 2108                     Delay  WTIV              NaN   17916.666667
# 2109            Drive Monopile  WTIV              NaN   13437.500000
# 2110  Release Transition Piece  WTIV              NaN   17916.666667
# 2111             Crane Reequip  WTIV              NaN    8958.333333
# 2112                  Lower TP  WTIV              NaN      20.736883
# 2115                   Bolt TP  WTIV              NaN   35833.333333
# 2118                  Jackdown  WTIV              NaN   12131.076389
# 2119           Position Onsite  WTIV              NaN   17916.666667
# 2120                    Jackup  WTIV              NaN   12131.076389
# 2121                 RovSurvey  WTIV              NaN    8958.333333
# 2124          Release Monopile  WTIV              NaN   26875.000000
# 2125            Upend Monopile  WTIV              NaN     143.084491
# 2126            Lower Monopile  WTIV              NaN       0.018001
# 2129             Crane Reequip  WTIV              NaN    8958.333333
# 2130            Drive Monopile  WTIV              NaN   13437.500000
# 2132  Release Transition Piece  WTIV              NaN   17916.666667
# 2135             Crane Reequip  WTIV              NaN    8958.333333
# 2136                  Lower TP  WTIV              NaN      20.736883
# 2140                   Bolt TP  WTIV              NaN   35833.333333
# 2141                  Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier   duration  hub_height   level location  max_waveheight  \
# 0                 0.5  72.000000         NaN  ACTION      NaN             NaN
# 12                NaN  12.000000       113.0  ACTION      NaN             NaN
# 23                NaN   8.000000       113.0  ACTION      NaN             NaN
# 32                NaN  12.000000       113.0  ACTION      NaN             NaN
# 37                NaN   8.000000       113.0  ACTION      NaN             NaN
# 46                NaN  12.000000       113.0  ACTION      NaN             NaN
# 51                NaN   8.000000       113.0  ACTION      NaN             NaN
# 58                NaN  12.000000       113.0  ACTION      NaN             NaN
# 64                NaN   8.000000       113.0  ACTION      NaN             NaN
# 74                NaN  12.000000       113.0  ACTION      NaN             NaN
# 81                NaN   8.000000       113.0  ACTION      NaN             NaN
# 90                NaN  12.000000       113.0  ACTION      NaN             NaN
# 98                NaN   8.000000       113.0  ACTION      NaN             NaN
# 108               NaN   8.266667         NaN  ACTION      NaN             NaN
# 109               NaN   2.000000         NaN  ACTION      NaN             NaN
# 110               NaN   1.354167       113.0  ACTION      NaN             NaN
# 112               NaN   1.000000       113.0  ACTION      NaN             NaN
# 115               NaN   3.000000         NaN  ACTION      NaN             NaN
# 116               NaN   0.015972       113.0  ACTION      NaN             NaN
# 117               NaN   0.000002       113.0  ACTION      NaN             NaN
# 118               NaN   1.000000       113.0  ACTION      NaN             NaN
# 121               NaN   1.500000       113.0  ACTION      NaN             NaN
# 124               NaN   2.000000         NaN  ACTION      NaN             NaN
# 125               NaN   1.000000       113.0  ACTION      NaN             NaN
# 126               NaN   0.002315       113.0  ACTION      NaN             NaN
# 128               NaN   4.000000       113.0  ACTION      NaN             NaN
# 131               NaN   1.354167       113.0  ACTION      NaN             NaN
# 134               NaN   2.000000         NaN  ACTION      NaN             NaN
# 135               NaN   1.354167       113.0  ACTION      NaN             NaN
# 137               NaN   1.000000       113.0  ACTION      NaN             NaN
# ...               ...        ...         ...     ...      ...             ...
# 2092              NaN   8.000000       113.0  ACTION      NaN             NaN
# 2096              NaN   8.266667         NaN  ACTION      NaN             NaN
# 2097              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2100              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2101              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2102              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2103              NaN  10.000000       113.0  ACTION      NaN             NaN
# 2104              NaN   0.015972       113.0  ACTION      NaN             NaN
# 2105              NaN   0.000002       113.0  ACTION      NaN             NaN
# 2106              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2108              NaN   2.000000       113.0  ACTION      NaN             NaN
# 2109              NaN   1.500000       113.0  ACTION      NaN             NaN
# 2110              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2111              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2112              NaN   0.002315       113.0  ACTION      NaN             NaN
# 2115              NaN   4.000000       113.0  ACTION      NaN             NaN
# 2118              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2119              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2120              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2121              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2124              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2125              NaN   0.015972       113.0  ACTION      NaN             NaN
# 2126              NaN   0.000002       113.0  ACTION      NaN             NaN
# 2129              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2130              NaN   1.500000       113.0  ACTION      NaN             NaN
# 2132              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2135              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2136              NaN   0.002315       113.0  ACTION      NaN             NaN
# 2140              NaN   4.000000       113.0  ACTION      NaN             NaN
# 2141              NaN   1.354167       113.0  ACTION      NaN             NaN
#
#       max_windspeed                 phase            phase_name  site_depth  \
# 0               NaN  MonopileInstallation                   NaN         NaN
# 12              NaN  MonopileInstallation  MonopileInstallation        22.5
# 23              NaN  MonopileInstallation  MonopileInstallation        22.5
# 32              NaN  MonopileInstallation  MonopileInstallation        22.5
# 37              NaN  MonopileInstallation  MonopileInstallation        22.5
# 46              NaN  MonopileInstallation  MonopileInstallation        22.5
# 51              NaN  MonopileInstallation  MonopileInstallation        22.5
# 58              NaN  MonopileInstallation  MonopileInstallation        22.5
# 64              NaN  MonopileInstallation  MonopileInstallation        22.5
# 74              NaN  MonopileInstallation  MonopileInstallation        22.5
# 81              NaN  MonopileInstallation  MonopileInstallation        22.5
# 90              NaN  MonopileInstallation  MonopileInstallation        22.5
# 98              NaN  MonopileInstallation  MonopileInstallation        22.5
# 108             NaN  MonopileInstallation                   NaN         NaN
# 109             NaN  MonopileInstallation                   NaN         NaN
# 110             NaN  MonopileInstallation  MonopileInstallation        22.5
# 112             NaN  MonopileInstallation  MonopileInstallation        22.5
# 115             NaN  MonopileInstallation                   NaN         NaN
# 116             NaN  MonopileInstallation  MonopileInstallation        22.5
# 117             NaN  MonopileInstallation  MonopileInstallation        22.5
# 118             NaN  MonopileInstallation  MonopileInstallation        22.5
# 121             NaN  MonopileInstallation  MonopileInstallation        22.5
# 124             NaN  MonopileInstallation                   NaN         NaN
# 125             NaN  MonopileInstallation  MonopileInstallation        22.5
# 126             NaN  MonopileInstallation  MonopileInstallation        22.5
# 128             NaN  MonopileInstallation  MonopileInstallation        22.5
# 131             NaN  MonopileInstallation  MonopileInstallation        22.5
# 134             NaN  MonopileInstallation                   NaN         NaN
# 135             NaN  MonopileInstallation  MonopileInstallation        22.5
# 137             NaN  MonopileInstallation  MonopileInstallation        22.5
# ...             ...                   ...                   ...         ...
# 2092            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2096            NaN  MonopileInstallation                   NaN         NaN
# 2097            NaN  MonopileInstallation                   NaN         NaN
# 2100            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2101            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2102            NaN  MonopileInstallation                   NaN         NaN
# 2103            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2104            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2105            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2106            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2108            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2109            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2110            NaN  MonopileInstallation                   NaN         NaN
# 2111            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2112            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2115            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2118            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2119            NaN  MonopileInstallation                   NaN         NaN
# 2120            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2121            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2124            NaN  MonopileInstallation                   NaN         NaN
# 2125            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2126            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2129            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2130            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2132            NaN  MonopileInstallation                   NaN         NaN
# 2135            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2136            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2140            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2141            NaN  MonopileInstallation  MonopileInstallation        22.5
#
#              time  transit_speed
# 0        0.000000            NaN
# 12      12.000000            NaN
# 23      20.000000            NaN
# 32      32.000000            NaN
# 37      40.000000            NaN
# 46      52.000000            NaN
# 51      60.000000            NaN
# 58      72.000000            NaN
# 64      80.000000            NaN
# 74      92.000000            NaN
# 81     100.000000            NaN
# 90     112.000000            NaN
# 98     120.000000            NaN
# 108    128.266667            NaN
# 109    130.266667            NaN
# 110    131.620833            NaN
# 112    132.620833            NaN
# 115    135.620833            NaN
# 116    135.636806            NaN
# 117    135.636808            NaN
# 118    136.636808            NaN
# 121    138.136808            NaN
# 124    140.136808            NaN
# 125    141.136808            NaN
# 126    141.139122            NaN
# 128    145.139122            NaN
# 131    146.493289            NaN
# 134    148.493289            NaN
# 135    149.847456            NaN
# 137    150.847456            NaN
# ...           ...            ...
# 2092  2041.144541            NaN
# 2096  2049.411208            NaN
# 2097  2051.411208            NaN
# 2100  2052.765374            NaN
# 2101  2053.765374            NaN
# 2102  2056.765374            NaN
# 2103  2066.765374            NaN
# 2104  2066.781346            NaN
# 2105  2066.781348            NaN
# 2106  2067.781348            NaN
# 2108  2069.781348            NaN
# 2109  2071.281348            NaN
# 2110  2073.281348            NaN
# 2111  2074.281348            NaN
# 2112  2074.283663            NaN
# 2115  2078.283663            NaN
# 2118  2079.637830            NaN
# 2119  2081.637830            NaN
# 2120  2082.991997            NaN
# 2121  2083.991997            NaN
# 2124  2086.991997            NaN
# 2125  2087.007969            NaN
# 2126  2087.007971            NaN
# 2129  2088.007971            NaN
# 2130  2089.507971            NaN
# 2132  2091.507971            NaN
# 2135  2092.507971            NaN
# 2136  2092.510286            NaN
# 2140  2096.510286            NaN
# 2141  2097.864452            NaN
#
# [775 rows x 16 columns]

# %% [markdown]
# ### Array cable design and installation

# %%
# Trip data
# project._phases['ArrayCableInstallation'].install_vessel.__dict__
# project._phases.keys()
# project._phases['ArraySystemDesign'].__dict__

project._phases['ArraySystemDesign'].detailed_output
# Out:
# {'array_system': {'cables': {'XLPE_630mm_66kV': {'cable_sections': [(2.957580471,
#       2),
#      (1.6199999999999999, 46),
#      (2.0403069939000003, 2)],
#     'linear_density': 45}}},
#  'array_system_num_strings': 5,
#  'array_system_total_length': 84.5157749298,
#  'array_system_length_by_type': {'XLPE_630mm_66kV': 84.5157749298},
#  'array_system_total_cost': 34397920.3964286,
#  'array_system_cost_by_type': {'XLPE_630mm_66kV': 34397920.3964286}}

# %%
# Installation and capital costs 
ac_time = np.round(project._phases['ArrayCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ac_install_cost = np.round(project._phases['ArrayCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ac_capital_cost = np.round(project._phases['ArraySystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
total_length = np.round(project._phases['ArraySystemDesign'].detailed_output['array_system_length_by_type']['XLPE_630mm_66kV'], 1)

print('Array cable total length: ',total_length , 'km')
print('Array cable install time: ', ac_time, 'days')
print('Array cable install cost: ', ac_install_cost, 'M Euros')
print('Array cable capital cost: ', ac_capital_cost, 'M Euros')
print('Array cable total cost: ', ac_capital_cost + ac_install_cost, 'M Euros')
# Out:
# Array cable total length:  84.5 km
# Array cable install time:  69.6 days
# Array cable install cost:  13.5 M Euros
# Array cable capital cost:  31.6 M Euros
# Array cable total cost:  45.1 M Euros

# %% [markdown]
# ### Export cable

# %%
project._phases['ExportSystemDesign'].detailed_output
# Out:
# {'export_system': {'interconnection_distance': 3,
#   'cable': {'linear_density': 80,
#    'sections': [45.0225],
#    'number': 2,
#    'cable_power': 342.9460597040872}},
#  'export_system_total_mass': 7203.6,
#  'export_system_total_length': 90.045,
#  'export_system_total_cost': 53756865.0,
#  'export_system_cable_power': 342.9460597040872}

# %%
# Installation and capital costs 
ec_time = np.round(project._phases['ExportCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ec_install_cost = np.round(project._phases['ExportCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_capital_cost = np.round(project._phases['ExportSystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_total_length = np.round(project._phases['ExportSystemDesign'].detailed_output['export_system_total_length'], 1)

print('Export cable total length: ',ec_total_length , 'km')
print('Export cable install time: ', ec_time, 'days')
print('Export cable install cost: ', ec_install_cost, 'M Euros')
print('Export cable capital cost: ', ec_capital_cost, 'M Euros')
print('Export cable total cost: ', ec_capital_cost + ec_install_cost, 'M Euros')
# Out:
# Export cable total length:  90.0 km
# Export cable install time:  15.7 days
# Export cable install cost:  20.5 M Euros
# Export cable capital cost:  49.5 M Euros
# Export cable total cost:  70.0 M Euros

# %% [markdown]
# ### Results - Old
#
# #### Array System Design

# %%
project._phases["ArraySystemDesign"].total_cable_length_by_type
# Out:
# {'XLPE_630mm_66kV': 84.5157749298}

# %%
project._phases['ArraySystemDesign'].num_full_strings
# Out:
# 4

# %%
project._phases['ArraySystemDesign'].num_partial_strings
# Out:
# 1

# %%
# Module outputs
project._phases['ArraySystemDesign'].total_phase_cost
# Out:
# 34397920.3964286

# %%
total = sum([v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()])
print(f"Total length: {total}")
# Out:
# Total length: 84.5157749298

# %%
cables = project._phases['ArraySystemDesign'].cables

total_mass = sum([
    cables[k].linear_density*v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()
])
total_mass
# Out:
# 3803.209871841

# %% [markdown]
# #### Export System Design

# %%
project._phases['ExportSystemDesign'].total_mass
# Out:
# 7203.6

# %%
project._phases['ExportSystemDesign'].num_cables
# Out:
# 2

# %%
project._phases['ExportSystemDesign'].cable.cable_power
# Out:
# 342.9460597040872

# %%
project._phases['ExportSystemDesign']._plant_capacity
# Out:
# 400

# %%
project._phases['ExportSystemDesign'].total_phase_cost * 2/3
# Out:
# 35837910.0

# %%
project._phases['ExportSystemDesign'].total_length*2/3
# Out:
# 60.03

# %% [markdown]
# #### Offshore Substation Design

# %%
project._phases["OffshoreSubstationDesign"].total_phase_cost
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-e88fdaf2ceb5> in <module>
# ----> 1 project._phases["OffshoreSubstationDesign"].total_phase_cost
#
# KeyError: 'OffshoreSubstationDesign'

# %%
project._phases["OffshoreSubstationDesign"].design_result

# %% [markdown]
# #### Monopile Design

# %%
# config['monopile']['weight'] * config['plant']['num_turbines'] * 3000 <<<<------ OLD

# %%
project._phases["MonopileDesign"].total_phase_cost # <<<---- NEW

# %%
project._phases["MonopileDesign"].design_result

# %% [markdown]
# #### Scour Protection Design

# %%
project._phases['ScourProtectionDesign'].design_result  # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionDesign'].protection_depth

# %%
project._phases['ScourProtectionDesign'].total_phase_cost # <---- NEW

# %% [markdown]
# #### Monopile Installation

# %%
project._phases['MonopileInstallation'].total_phase_time / (8760 / 12)

# %%
project._phases['MonopileInstallation'].total_phase_cost

# %%
project._phases['MonopileInstallation'].detailed_output

# %%
project._phases['MonopileInstallation'].total_phase_time / 67

# %%
mi = project.project_dataframe.loc[project.project_dataframe['phase']=='MonopileInstallation']

mi.groupby('action').sum()['duration']

# %% [markdown]
# #### Scour Protection Installation

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / (8760 / 12) # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].total_phase_cost # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].detailed_output

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / 67  # <--- NEW, revised protection depth

# %%
spi = project.project_dataframe.loc[project.project_dataframe['phase']=='ScourProtectionInstallation']

spi.groupby('action').sum()['duration']

# %% [markdown]
# #### Turbine Installation

# %%
project._phases['TurbineInstallation'].total_phase_time / (8760 / 12)  # NEW, turbine installation revised to eliminate too many crane reequips between blade installations

# %%
project._phases['TurbineInstallation'].total_phase_cost  # NEW, see above

# %%
project._phases['TurbineInstallation'].detailed_output

# %%
project._phases['TurbineInstallation'].total_phase_time / 67  # NEW, see above

# %%
ti = project.project_dataframe.loc[project.project_dataframe['phase']=='TurbineInstallation']

ti.groupby('action').sum()['duration']

# %%
project._phases['TurbineInstallation'].wtiv.trip_data

# %% [markdown]
# #### Array System Installation

# %%
project._phases['ArrayCableInstallation'].total_phase_time / (8760 / 12)  # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ArrayCableInstallation'].total_phase_cost

# %%
project._phases['ArrayCableInstallation'].detailed_output

# %%
asi = project.project_dataframe.loc[project.project_dataframe['phase']=='ArrayCableInstallation']

asi.groupby('action').sum()['duration']

# %% [markdown]
# #### Export System Installation

# %%
project._phases['ExportCableInstallation'].total_phase_time # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].total_phase_cost # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].detailed_output

# %%
esi = project.project_dataframe.loc[project.project_dataframe['phase']=='ExportCableInstallation']

esi.groupby('action').sum()['duration']

# %% [markdown]
# #### Offshore Substation Installation

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_time / (24)

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_cost

# %%
project._phases['OffshoreSubstationInstallation'].detailed_output

# %%
osi = project.project_dataframe.loc[project.project_dataframe['phase']=='OffshoreSubstationInstallation']

osi.groupby('action').sum()['duration']

# %%
project.project_dataframe["phase"].unique()

# %%
project.design_results

# %%
project.project_dataframe.time.max() / (8760 / 12)

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_costs).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Cost ($USD)')

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_times).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Time (h)')

# %%
phases = project.phase_dates.keys()
_start_dates = [project.phase_dates[p]['start'] for p in phases]
start_floats = [plt_dates.datestr2num(i) for i in _start_dates]
_end_dates = [project.phase_dates[p]['end'] for p in phases]
end_floats = [plt_dates.datestr2num(i) for i in _end_dates]

# %%
data = pd.DataFrame(columns=phases, data=[start_floats, end_floats], index=['Start', 'End']).T
data = data.reset_index().rename(columns={'index': 'Phase'})
data['Type'] = 'Model'

validation_data = data.copy()
validation_data = validation_data.set_index(keys='Phase')
validation_data.loc['MonopileInstallation', 'End'] = plt_dates.datestr2num("08/03/16 00:00")
validation_data.loc['ScourProtectionInstallation', 'End'] = plt_dates.datestr2num("09/30/16 00:00")
validation_data.loc['TurbineInstallation', 'End'] = plt_dates.datestr2num("09/04/17 00:00")
validation_data.loc['ArrayCableInstallation', 'End'] = plt_dates.datestr2num("08/27/16 00:00")
validation_data.loc['ExportCableInstallation', 'End'] = plt_dates.datestr2num("04/21/16 00:00")
validation_data['Type'] = 'Dudgeon'
validation_data = validation_data.reset_index().rename(columns={'index': 'Phase'})

data = pd.concat([data, validation_data])
data['Time'] = data['End'] - data['Start']
data

# %%
import seaborn as sns
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='Phase', y='Time', hue='Type', data=data, ax=axis)

for tick in axis.get_xticklabels():
    tick.set_rotation(90)
    
# axis.yaxis_date()
# fig.autofmt_xdate()

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='End', y='Phase', data=data, ax=axis, zorder=3, hue='Type')
axis = sns.barplot(x='Start', y='Phase', data=data, ax=axis, palette={'Model': 'w', 'Dudgeon': 'w'}, zorder=5, hue='Type')

axis.set_xlim(data['Start'].min()-10, data['End'].max()+10)

# Legend
handles, labels = axis.get_legend_handles_labels()
axis.legend(handles[:2], labels[:2], fontsize=8)

# Formatting
axis.set_xlabel('')
# axis.grid(axis='x', which='major', lw=0.5, zorder=4)
# Tick parameters
axis.tick_params(axis='both', labelsize=8, width=0.5, length=3)

# Plot formatting
for ax in ['top', 'bottom', 'left', 'right']:
    axis.spines[ax].set_linewidth(0.5)
    axis.spines[ax].set_zorder(20)

axis.xaxis_date()
fig.autofmt_xdate()
