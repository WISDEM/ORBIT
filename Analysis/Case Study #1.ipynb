# %% [markdown]
# ### Cost model benchmarking - case study #1
#
# Loosely based on Dudgeon Wind Farm (400 MW, 8MW turbines)
#
# National Renewable Energy Lab
#
# Matt Shields, Jake Nunemaker
#
# Updated: 2/17/2020

# %%
import os
import sys
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as plt_dates

import ORBIT
print(f"Using ORBIT version {ORBIT.__version__}.")
from ORBIT import ProjectManager


usd_to_euro = 0.92
# Out:
# Using ORBIT version 0+unknown.

# %% [markdown]
# #### Weather File

# %%
filepath = os.path.join('library', 'weather', 'dudgeon_wave_100m_wind.csv')
weather = pd.read_csv(filepath).set_index(keys='datetime')
weather.describe()
# Out:
#           windspeed    waveheight
# count  20616.000000  20616.000000
# mean       9.138532      1.183350
# std        4.249767      0.667603
# min        0.121744      0.170372
# 25%        5.980583      0.698537
# 50%        8.916669      1.027665
# 75%       11.878717      1.507961
# max       25.680700      5.773216

# %% [markdown]
# #### ORBIT Configuration

# %%
phases = [
    # Substructures
    'MonopileInstallation',
#     'ScourProtectionDesign',
#     'ScourProtectionInstallation',
    
    # Turbines
    'TurbineInstallation',
    
#     # Electrical
    'ArraySystemDesign',
    'ArrayCableInstallation',
    'ExportSystemDesign',
    'ExportCableInstallation',
    'OffshoreSubstationDesign',
    'OffshoreSubstationInstallation'
]

required_config = ProjectManager.compile_input_dict(phases)
# required_config

# %%
config = {
    # Substations
#     "num_substations": 1,
    
    # Vessels
#     'scour_protection_install_vessel': 'ExampleScour',
#     'trench_dig_vessel': 'StematSpirit',
#     'array_cable_lay_vessel': 'cable_lay_vessel',
#     'export_cable_lay_vessel': 'StematSpirit',
#     "oss_install_vessel": "OlegStrashnov",  # Actually vessel from SPT Offshore
    
    # Site/plant
    'site': {
        'depth': 22.5,
        'distance': 124,
        'distance_to_landfall': 42,
        'distance_to_beach': 0,
        'distance_to_interconnection': 3,
        'mean_windspeed': 9.13
    },
    
    'plant': {
        'layout': 'grid',
        'num_turbines': 50,
        'row_spacing': 7,
        'turbine_spacing': 9,
        'substation_distance': 1
    },
    
    'port': {
        'num_cranes': 1,
        'monthly_rate': 2000000,
        "name": "Green Port"
    },
    
    # Turbine + components
    'turbine': '8MW_generic',

    # Substructure components
    'substructure': {'diameter': 7.2},
    'monopile': {
        'type': 'Monopile',
        'length': 69,
        'diameter': 7.2,
        'deck_space': 496.8,
        'mass': 800,
        'monopile_steel_cost' : 2000 / usd_to_euro,
    },
    
    'transition_piece': {
        'type': 'Transition Piece',
        'deck_space': 100,
        'mass': 400,
        'transition_piece_steel_cost' : 2000 / usd_to_euro,
    },
    
#     'scour_protection_design': {
#         'cost_per_tonne': 40,
#     },
    
    # Electrical
    'array_system_design': {
        'cables': 'XLPE_630mm_66kV'
    },
    
    'array_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system_design': {
        'cables': 'XLPE_1000mm_220kV',
        'percent_added_length': 0
    },
    
#     "offshore_substation_topside": {
#         "type": "Topside",
#         "deck_space": 200,
#         "weight": 2000,
#     },
#     "offshore_substation_substructure": {
#         "type": "Monopile",
#         "deck_space": 500,
#         "weight": 1850,
#         "length": 69,  # Assumed to be the same as monopile length
#     },


    # Phase specific configurations
    'MonopileInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine',  
        
    },
    
    'TurbineInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine'
    },
    
    'ArrayCableInstallation': {
        'array_cable_install_vessel' : 'cable_lay_vessel'
    }, 
    
    'ExportCableInstallation': {
        'export_cable_install_vessel' : 'cable_lay_vessel'
    },
    
    'OffshoreSubstationInstallation': {
        "num_feeders": 1,
        "feeder": "future_large_feeder",
        "oss_install_vessel": "heavy_lift_vessel"
    },    
    
    # Phases
    'design_phases': [
#         "MonopileDesign",
#         'ScourProtectionDesign',
        'ArraySystemDesign',
        'ExportSystemDesign',
        'OffshoreSubstationDesign'
    ],
    
    'install_phases': {
        'MonopileInstallation': '07/01/2016',         # Updated dates 
#         'ScourProtectionInstallation': '09/01/2016',  # Placed at the end of the monopile installation
        'TurbineInstallation': '07/01/2016',
        'ArrayCableInstallation': '07/01/2016',
        'ExportCableInstallation': '07/01/2016',
        'OffshoreSubstationInstallation': '07/01/2016'
    }
}

# %%
path = os.path.join(os.getcwd(), "library")
project = ProjectManager(config, weather=weather, library_path=path)
# Out:
# ORBIT library intialized at 'C:\Users\mshields\Documents\Analysis Tools\NREL\ORBIT\Analysis\library'

# %%
project.run_project()

# %% [markdown]
# # Results
#
# ### Turbine installation

# %%
# Trip data
project._phases['TurbineInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_mass=1506, deck_space=1942, items={TowerSection: 4, Nacelle: 2, Blade: 6})]

# %%
# Installation costs 
turb_time = np.round(project._phases['TurbineInstallation'].total_phase_time * (1/24) ,1 ) # Convert hours to days
turb_cost = np.round(project._phases['TurbineInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Turbine install time: ', turb_time, 'days')
print('Turbine install cost: ', turb_cost, 'M Euros')
# Out:
# Turbine install time:  149.1 days
# Turbine install cost:  38.8 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='TurbineInstallation']
# Out:
#                      action agent  cable_lay_speed           cost  \
# 1                  Mobilize  WTIV              NaN  322500.000000
# 7      Fasten Tower Section  WTIV              NaN   35833.333333
# 13     Fasten Tower Section  WTIV              NaN   35833.333333
# 15           Fasten Nacelle  WTIV              NaN   35833.333333
# 19             Fasten Blade  WTIV              NaN   13437.500000
# 22             Fasten Blade  WTIV              NaN   13437.500000
# 24             Fasten Blade  WTIV              NaN   13437.500000
# 29     Fasten Tower Section  WTIV              NaN   35833.333333
# 31     Fasten Tower Section  WTIV              NaN   35833.333333
# 34           Fasten Nacelle  WTIV              NaN   35833.333333
# 35             Fasten Blade  WTIV              NaN   13437.500000
# 36             Fasten Blade  WTIV              NaN   13437.500000
# 40             Fasten Blade  WTIV              NaN   13437.500000
# 44     Fasten Tower Section  WTIV              NaN   35833.333333
# 49     Fasten Tower Section  WTIV              NaN   35833.333333
# 51           Fasten Nacelle  WTIV              NaN   35833.333333
# 52             Fasten Blade  WTIV              NaN   13437.500000
# 53             Fasten Blade  WTIV              NaN   13437.500000
# 55             Fasten Blade  WTIV              NaN   13437.500000
# 59     Fasten Tower Section  WTIV              NaN   35833.333333
# 65     Fasten Tower Section  WTIV              NaN   35833.333333
# 72           Fasten Nacelle  WTIV              NaN   35833.333333
# 73             Fasten Blade  WTIV              NaN   13437.500000
# 76             Fasten Blade  WTIV              NaN   13437.500000
# 78             Fasten Blade  WTIV              NaN   13437.500000
# 83                  Transit  WTIV              NaN   74055.555556
# 86          Position Onsite  WTIV              NaN   17916.666667
# 87                   Jackup  WTIV              NaN   12131.076389
# 90    Release Tower Section  WTIV              NaN   26875.000000
# 91       Lift Tower Section  WTIV              NaN     118.200231
# ...                     ...   ...              ...            ...
# 2749          Release Blade  WTIV              NaN    8958.333333
# 2750             Lift Blade  WTIV              NaN     234.326775
# 2751           Attach Blade  WTIV              NaN   31354.166667
# 2752          Release Blade  WTIV              NaN    8958.333333
# 2753             Lift Blade  WTIV              NaN     234.326775
# 2754           Attach Blade  WTIV              NaN   31354.166667
# 2755               Jackdown  WTIV              NaN   12131.076389
# 2756        Position Onsite  WTIV              NaN   17916.666667
# 2757                 Jackup  WTIV              NaN   12131.076389
# 2758  Release Tower Section  WTIV              NaN   26875.000000
# 2759     Lift Tower Section  WTIV              NaN     118.200231
# 2760   Attach Tower Section  WTIV              NaN   53750.000000
# 2761  Release Tower Section  WTIV              NaN   26875.000000
# 2762     Lift Tower Section  WTIV              NaN     236.400463
# 2763   Attach Tower Section  WTIV              NaN   53750.000000
# 2764        Release Nacelle  WTIV              NaN   26875.000000
# 2765                Reequip  WTIV              NaN    8958.333333
# 2766           Lift Nacelle  WTIV              NaN     234.326775
# 2767         Attach Nacelle  WTIV              NaN   53750.000000
# 2768                Reequip  WTIV              NaN    8958.333333
# 2769          Release Blade  WTIV              NaN    8958.333333
# 2770             Lift Blade  WTIV              NaN     234.326775
# 2771           Attach Blade  WTIV              NaN   31354.166667
# 2772          Release Blade  WTIV              NaN    8958.333333
# 2773             Lift Blade  WTIV              NaN     234.326775
# 2774           Attach Blade  WTIV              NaN   31354.166667
# 2775          Release Blade  WTIV              NaN    8958.333333
# 2776             Lift Blade  WTIV              NaN     234.326775
# 2777           Attach Blade  WTIV              NaN   31354.166667
# 2778               Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier   duration  hub_height   level location  max_waveheight  \
# 1                 0.5  72.000000         NaN  ACTION      NaN             NaN
# 7                 NaN   4.000000       113.0  ACTION      NaN             NaN
# 13                NaN   4.000000       113.0  ACTION      NaN             NaN
# 15                NaN   4.000000       113.0  ACTION      NaN             NaN
# 19                NaN   1.500000       113.0  ACTION      NaN             NaN
# 22                NaN   1.500000       113.0  ACTION      NaN             NaN
# 24                NaN   1.500000       113.0  ACTION      NaN             NaN
# 29                NaN   4.000000       113.0  ACTION      NaN             NaN
# 31                NaN   4.000000       113.0  ACTION      NaN             NaN
# 34                NaN   4.000000       113.0  ACTION      NaN             NaN
# 35                NaN   1.500000       113.0  ACTION      NaN             NaN
# 36                NaN   1.500000       113.0  ACTION      NaN             NaN
# 40                NaN   1.500000       113.0  ACTION      NaN             NaN
# 44                NaN   4.000000       113.0  ACTION      NaN             NaN
# 49                NaN   4.000000       113.0  ACTION      NaN             NaN
# 51                NaN   4.000000       113.0  ACTION      NaN             NaN
# 52                NaN   1.500000       113.0  ACTION      NaN             NaN
# 53                NaN   1.500000       113.0  ACTION      NaN             NaN
# 55                NaN   1.500000       113.0  ACTION      NaN             NaN
# 59                NaN   4.000000       113.0  ACTION      NaN             NaN
# 65                NaN   4.000000       113.0  ACTION      NaN             NaN
# 72                NaN   4.000000       113.0  ACTION      NaN             NaN
# 73                NaN   1.500000       113.0  ACTION      NaN             NaN
# 76                NaN   1.500000       113.0  ACTION      NaN             NaN
# 78                NaN   1.500000       113.0  ACTION      NaN             NaN
# 83                NaN   8.266667         NaN  ACTION      NaN             NaN
# 86                NaN   2.000000         NaN  ACTION      NaN             NaN
# 87                NaN   1.354167       113.0  ACTION      NaN             NaN
# 90                NaN   3.000000         NaN  ACTION      NaN             NaN
# 91                NaN   0.013194       113.0  ACTION      NaN             NaN
# ...               ...        ...         ...     ...      ...             ...
# 2749              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2750              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2751              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2752              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2753              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2754              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2755              NaN   1.354167         NaN  ACTION      NaN             NaN
# 2756              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2757              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2758              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2759              NaN   0.013194       113.0  ACTION      NaN             NaN
# 2760              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2761              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2762              NaN   0.026389       113.0  ACTION      NaN             NaN
# 2763              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2764              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2765              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2766              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2767              NaN   6.000000       113.0  ACTION      NaN             NaN
# 2768              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2769              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2770              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2771              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2772              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2773              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2774              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2775              NaN   1.000000         NaN  ACTION      NaN             NaN
# 2776              NaN   0.026157       113.0  ACTION      NaN             NaN
# 2777              NaN   3.500000       113.0  ACTION      NaN             NaN
# 2778              NaN   1.354167         NaN  ACTION      NaN             NaN
#
#       max_windspeed                phase           phase_name  site_depth  \
# 1               NaN  TurbineInstallation                  NaN         NaN
# 7               NaN  TurbineInstallation  TurbineInstallation        22.5
# 13              NaN  TurbineInstallation  TurbineInstallation        22.5
# 15              NaN  TurbineInstallation  TurbineInstallation        22.5
# 19              NaN  TurbineInstallation  TurbineInstallation        22.5
# 22              NaN  TurbineInstallation  TurbineInstallation        22.5
# 24              NaN  TurbineInstallation  TurbineInstallation        22.5
# 29              NaN  TurbineInstallation  TurbineInstallation        22.5
# 31              NaN  TurbineInstallation  TurbineInstallation        22.5
# 34              NaN  TurbineInstallation  TurbineInstallation        22.5
# 35              NaN  TurbineInstallation  TurbineInstallation        22.5
# 36              NaN  TurbineInstallation  TurbineInstallation        22.5
# 40              NaN  TurbineInstallation  TurbineInstallation        22.5
# 44              NaN  TurbineInstallation  TurbineInstallation        22.5
# 49              NaN  TurbineInstallation  TurbineInstallation        22.5
# 51              NaN  TurbineInstallation  TurbineInstallation        22.5
# 52              NaN  TurbineInstallation  TurbineInstallation        22.5
# 53              NaN  TurbineInstallation  TurbineInstallation        22.5
# 55              NaN  TurbineInstallation  TurbineInstallation        22.5
# 59              NaN  TurbineInstallation  TurbineInstallation        22.5
# 65              NaN  TurbineInstallation  TurbineInstallation        22.5
# 72              NaN  TurbineInstallation  TurbineInstallation        22.5
# 73              NaN  TurbineInstallation  TurbineInstallation        22.5
# 76              NaN  TurbineInstallation  TurbineInstallation        22.5
# 78              NaN  TurbineInstallation  TurbineInstallation        22.5
# 83              NaN  TurbineInstallation                  NaN         NaN
# 86              NaN  TurbineInstallation                  NaN         NaN
# 87              NaN  TurbineInstallation  TurbineInstallation        22.5
# 90              NaN  TurbineInstallation                  NaN         NaN
# 91              NaN  TurbineInstallation  TurbineInstallation        22.5
# ...             ...                  ...                  ...         ...
# 2749            NaN  TurbineInstallation                  NaN         NaN
# 2750            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2751            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2752            NaN  TurbineInstallation                  NaN         NaN
# 2753            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2754            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2755            NaN  TurbineInstallation                  NaN         NaN
# 2756            NaN  TurbineInstallation                  NaN         NaN
# 2757            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2758            NaN  TurbineInstallation                  NaN         NaN
# 2759            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2760            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2761            NaN  TurbineInstallation                  NaN         NaN
# 2762            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2763            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2764            NaN  TurbineInstallation                  NaN         NaN
# 2765            NaN  TurbineInstallation                  NaN         NaN
# 2766            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2767            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2768            NaN  TurbineInstallation                  NaN         NaN
# 2769            NaN  TurbineInstallation                  NaN         NaN
# 2770            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2771            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2772            NaN  TurbineInstallation                  NaN         NaN
# 2773            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2774            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2775            NaN  TurbineInstallation                  NaN         NaN
# 2776            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2777            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2778            NaN  TurbineInstallation                  NaN         NaN
#
#              time  transit_speed
# 1        0.000000            NaN
# 7        4.000000            NaN
# 13       8.000000            NaN
# 15      12.000000            NaN
# 19      13.500000            NaN
# 22      15.000000            NaN
# 24      16.500000            NaN
# 29      20.500000            NaN
# 31      24.500000            NaN
# 34      28.500000            NaN
# 35      30.000000            NaN
# 36      31.500000            NaN
# 40      33.000000            NaN
# 44      37.000000            NaN
# 49      41.000000            NaN
# 51      45.000000            NaN
# 52      46.500000            NaN
# 53      48.000000            NaN
# 55      49.500000            NaN
# 59      53.500000            NaN
# 65      57.500000            NaN
# 72      61.500000            NaN
# 73      63.000000            NaN
# 76      64.500000            NaN
# 78      66.000000            NaN
# 83      74.266667            NaN
# 86      76.266667            NaN
# 87      77.620833            NaN
# 90      80.620833            NaN
# 91      80.634028            NaN
# ...           ...            ...
# 2749  3520.534954            NaN
# 2750  3520.561111            NaN
# 2751  3524.061111            NaN
# 2752  3525.061111            NaN
# 2753  3525.087269            NaN
# 2754  3528.587269            NaN
# 2755  3529.941435            NaN
# 2756  3531.941435            NaN
# 2757  3533.295602            NaN
# 2758  3536.295602            NaN
# 2759  3536.308796            NaN
# 2760  3542.308796            NaN
# 2761  3545.308796            NaN
# 2762  3545.335185            NaN
# 2763  3551.335185            NaN
# 2764  3554.335185            NaN
# 2765  3555.335185            NaN
# 2766  3555.361343            NaN
# 2767  3561.361343            NaN
# 2768  3562.361343            NaN
# 2769  3563.361343            NaN
# 2770  3563.387500            NaN
# 2771  3566.887500            NaN
# 2772  3567.887500            NaN
# 2773  3567.913657            NaN
# 2774  3571.413657            NaN
# 2775  3572.413657            NaN
# 2776  3572.439815            NaN
# 2777  3575.939815            NaN
# 2778  3577.293981            NaN
#
# [1493 rows x 16 columns]

# %% [markdown]
# ### Monopile design and installation

# %%
# Trip data
project._phases['MonopileInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_mass=2400, deck_space=1193.6, items={Monopile: 2, TransitionPiece: 2})]

# %%
# Installation and capital costs 
mono_time = np.round(project._phases['MonopileInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
mono_install_cost = np.round(project._phases['MonopileInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
mono_capital_cost = np.round(((config['monopile']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['monopile']['monopile_steel_cost']) +
                     (config['transition_piece']['mass'] * 
                     config['plant']['num_turbines'] * 
                     config['transition_piece']['transition_piece_steel_cost']))* 1e-6 * usd_to_euro , 1)

print('Monopile install time: ', mono_time, 'days')
print('Monopile install cost: ', mono_install_cost, 'M Euros')
print('Monopile capital cost: ', mono_capital_cost, 'M Euros')
print('Monopile total cost: ', mono_capital_cost + mono_install_cost, 'M Euros')
# Out:
# Monopile install time:  87.4 days
# Monopile install cost:  22.9 M Euros
# Monopile capital cost:  120.0 M Euros
# Monopile total cost:  142.9 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='MonopileInstallation']
# Out:
#                         action agent  cable_lay_speed           cost  \
# 0                     Mobilize  WTIV              NaN  322500.000000
# 14             Fasten Monopile  WTIV              NaN  107500.000000
# 28     Fasten Transition Piece  WTIV              NaN   71666.666667
# 39             Fasten Monopile  WTIV              NaN  107500.000000
# 48     Fasten Transition Piece  WTIV              NaN   71666.666667
# 57             Fasten Monopile  WTIV              NaN  107500.000000
# 71     Fasten Transition Piece  WTIV              NaN   71666.666667
# 81             Fasten Monopile  WTIV              NaN  107500.000000
# 88     Fasten Transition Piece  WTIV              NaN   71666.666667
# 99             Fasten Monopile  WTIV              NaN  107500.000000
# 106    Fasten Transition Piece  WTIV              NaN   71666.666667
# 115            Fasten Monopile  WTIV              NaN  107500.000000
# 123    Fasten Transition Piece  WTIV              NaN   71666.666667
# 133                    Transit  WTIV              NaN   74055.555556
# 134            Position Onsite  WTIV              NaN   17916.666667
# 135                     Jackup  WTIV              NaN   12131.076389
# 137                  RovSurvey  WTIV              NaN    8958.333333
# 140           Release Monopile  WTIV              NaN   26875.000000
# 141             Upend Monopile  WTIV              NaN     143.084491
# 142             Lower Monopile  WTIV              NaN       0.018001
# 143              Crane Reequip  WTIV              NaN    8958.333333
# 146             Drive Monopile  WTIV              NaN   13437.500000
# 149   Release Transition Piece  WTIV              NaN   17916.666667
# 150              Crane Reequip  WTIV              NaN    8958.333333
# 151                   Lower TP  WTIV              NaN      20.736883
# 153                    Bolt TP  WTIV              NaN   35833.333333
# 156                   Jackdown  WTIV              NaN   12131.076389
# 159            Position Onsite  WTIV              NaN   17916.666667
# 160                     Jackup  WTIV              NaN   12131.076389
# 162                  RovSurvey  WTIV              NaN    8958.333333
# ...                        ...   ...              ...            ...
# 2117   Fasten Transition Piece  WTIV              NaN   71666.666667
# 2121                   Transit  WTIV              NaN   74055.555556
# 2122           Position Onsite  WTIV              NaN   17916.666667
# 2125                    Jackup  WTIV              NaN   12131.076389
# 2126                 RovSurvey  WTIV              NaN    8958.333333
# 2127          Release Monopile  WTIV              NaN   26875.000000
# 2128                     Delay  WTIV              NaN   89583.333333
# 2129            Upend Monopile  WTIV              NaN     143.084491
# 2130            Lower Monopile  WTIV              NaN       0.018001
# 2131             Crane Reequip  WTIV              NaN    8958.333333
# 2133                     Delay  WTIV              NaN   17916.666667
# 2134            Drive Monopile  WTIV              NaN   13437.500000
# 2135  Release Transition Piece  WTIV              NaN   17916.666667
# 2136             Crane Reequip  WTIV              NaN    8958.333333
# 2137                  Lower TP  WTIV              NaN      20.736883
# 2140                   Bolt TP  WTIV              NaN   35833.333333
# 2143                  Jackdown  WTIV              NaN   12131.076389
# 2144           Position Onsite  WTIV              NaN   17916.666667
# 2145                    Jackup  WTIV              NaN   12131.076389
# 2146                 RovSurvey  WTIV              NaN    8958.333333
# 2149          Release Monopile  WTIV              NaN   26875.000000
# 2150            Upend Monopile  WTIV              NaN     143.084491
# 2151            Lower Monopile  WTIV              NaN       0.018001
# 2154             Crane Reequip  WTIV              NaN    8958.333333
# 2155            Drive Monopile  WTIV              NaN   13437.500000
# 2157  Release Transition Piece  WTIV              NaN   17916.666667
# 2160             Crane Reequip  WTIV              NaN    8958.333333
# 2161                  Lower TP  WTIV              NaN      20.736883
# 2165                   Bolt TP  WTIV              NaN   35833.333333
# 2166                  Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier   duration  hub_height   level location  max_waveheight  \
# 0                 0.5  72.000000         NaN  ACTION      NaN             NaN
# 14                NaN  12.000000       113.0  ACTION      NaN             NaN
# 28                NaN   8.000000       113.0  ACTION      NaN             NaN
# 39                NaN  12.000000       113.0  ACTION      NaN             NaN
# 48                NaN   8.000000       113.0  ACTION      NaN             NaN
# 57                NaN  12.000000       113.0  ACTION      NaN             NaN
# 71                NaN   8.000000       113.0  ACTION      NaN             NaN
# 81                NaN  12.000000       113.0  ACTION      NaN             NaN
# 88                NaN   8.000000       113.0  ACTION      NaN             NaN
# 99                NaN  12.000000       113.0  ACTION      NaN             NaN
# 106               NaN   8.000000       113.0  ACTION      NaN             NaN
# 115               NaN  12.000000       113.0  ACTION      NaN             NaN
# 123               NaN   8.000000       113.0  ACTION      NaN             NaN
# 133               NaN   8.266667         NaN  ACTION      NaN             NaN
# 134               NaN   2.000000         NaN  ACTION      NaN             NaN
# 135               NaN   1.354167       113.0  ACTION      NaN             NaN
# 137               NaN   1.000000       113.0  ACTION      NaN             NaN
# 140               NaN   3.000000         NaN  ACTION      NaN             NaN
# 141               NaN   0.015972       113.0  ACTION      NaN             NaN
# 142               NaN   0.000002       113.0  ACTION      NaN             NaN
# 143               NaN   1.000000       113.0  ACTION      NaN             NaN
# 146               NaN   1.500000       113.0  ACTION      NaN             NaN
# 149               NaN   2.000000         NaN  ACTION      NaN             NaN
# 150               NaN   1.000000       113.0  ACTION      NaN             NaN
# 151               NaN   0.002315       113.0  ACTION      NaN             NaN
# 153               NaN   4.000000       113.0  ACTION      NaN             NaN
# 156               NaN   1.354167       113.0  ACTION      NaN             NaN
# 159               NaN   2.000000         NaN  ACTION      NaN             NaN
# 160               NaN   1.354167       113.0  ACTION      NaN             NaN
# 162               NaN   1.000000       113.0  ACTION      NaN             NaN
# ...               ...        ...         ...     ...      ...             ...
# 2117              NaN   8.000000       113.0  ACTION      NaN             NaN
# 2121              NaN   8.266667         NaN  ACTION      NaN             NaN
# 2122              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2125              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2126              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2127              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2128              NaN  10.000000       113.0  ACTION      NaN             NaN
# 2129              NaN   0.015972       113.0  ACTION      NaN             NaN
# 2130              NaN   0.000002       113.0  ACTION      NaN             NaN
# 2131              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2133              NaN   2.000000       113.0  ACTION      NaN             NaN
# 2134              NaN   1.500000       113.0  ACTION      NaN             NaN
# 2135              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2136              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2137              NaN   0.002315       113.0  ACTION      NaN             NaN
# 2140              NaN   4.000000       113.0  ACTION      NaN             NaN
# 2143              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2144              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2145              NaN   1.354167       113.0  ACTION      NaN             NaN
# 2146              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2149              NaN   3.000000         NaN  ACTION      NaN             NaN
# 2150              NaN   0.015972       113.0  ACTION      NaN             NaN
# 2151              NaN   0.000002       113.0  ACTION      NaN             NaN
# 2154              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2155              NaN   1.500000       113.0  ACTION      NaN             NaN
# 2157              NaN   2.000000         NaN  ACTION      NaN             NaN
# 2160              NaN   1.000000       113.0  ACTION      NaN             NaN
# 2161              NaN   0.002315       113.0  ACTION      NaN             NaN
# 2165              NaN   4.000000       113.0  ACTION      NaN             NaN
# 2166              NaN   1.354167       113.0  ACTION      NaN             NaN
#
#       max_windspeed                 phase            phase_name  site_depth  \
# 0               NaN  MonopileInstallation                   NaN         NaN
# 14              NaN  MonopileInstallation  MonopileInstallation        22.5
# 28              NaN  MonopileInstallation  MonopileInstallation        22.5
# 39              NaN  MonopileInstallation  MonopileInstallation        22.5
# 48              NaN  MonopileInstallation  MonopileInstallation        22.5
# 57              NaN  MonopileInstallation  MonopileInstallation        22.5
# 71              NaN  MonopileInstallation  MonopileInstallation        22.5
# 81              NaN  MonopileInstallation  MonopileInstallation        22.5
# 88              NaN  MonopileInstallation  MonopileInstallation        22.5
# 99              NaN  MonopileInstallation  MonopileInstallation        22.5
# 106             NaN  MonopileInstallation  MonopileInstallation        22.5
# 115             NaN  MonopileInstallation  MonopileInstallation        22.5
# 123             NaN  MonopileInstallation  MonopileInstallation        22.5
# 133             NaN  MonopileInstallation                   NaN         NaN
# 134             NaN  MonopileInstallation                   NaN         NaN
# 135             NaN  MonopileInstallation  MonopileInstallation        22.5
# 137             NaN  MonopileInstallation  MonopileInstallation        22.5
# 140             NaN  MonopileInstallation                   NaN         NaN
# 141             NaN  MonopileInstallation  MonopileInstallation        22.5
# 142             NaN  MonopileInstallation  MonopileInstallation        22.5
# 143             NaN  MonopileInstallation  MonopileInstallation        22.5
# 146             NaN  MonopileInstallation  MonopileInstallation        22.5
# 149             NaN  MonopileInstallation                   NaN         NaN
# 150             NaN  MonopileInstallation  MonopileInstallation        22.5
# 151             NaN  MonopileInstallation  MonopileInstallation        22.5
# 153             NaN  MonopileInstallation  MonopileInstallation        22.5
# 156             NaN  MonopileInstallation  MonopileInstallation        22.5
# 159             NaN  MonopileInstallation                   NaN         NaN
# 160             NaN  MonopileInstallation  MonopileInstallation        22.5
# 162             NaN  MonopileInstallation  MonopileInstallation        22.5
# ...             ...                   ...                   ...         ...
# 2117            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2121            NaN  MonopileInstallation                   NaN         NaN
# 2122            NaN  MonopileInstallation                   NaN         NaN
# 2125            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2126            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2127            NaN  MonopileInstallation                   NaN         NaN
# 2128            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2129            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2130            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2131            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2133            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2134            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2135            NaN  MonopileInstallation                   NaN         NaN
# 2136            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2137            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2140            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2143            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2144            NaN  MonopileInstallation                   NaN         NaN
# 2145            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2146            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2149            NaN  MonopileInstallation                   NaN         NaN
# 2150            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2151            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2154            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2155            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2157            NaN  MonopileInstallation                   NaN         NaN
# 2160            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2161            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2165            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2166            NaN  MonopileInstallation  MonopileInstallation        22.5
#
#              time  transit_speed
# 0        0.000000            NaN
# 14      12.000000            NaN
# 28      20.000000            NaN
# 39      32.000000            NaN
# 48      40.000000            NaN
# 57      52.000000            NaN
# 71      60.000000            NaN
# 81      72.000000            NaN
# 88      80.000000            NaN
# 99      92.000000            NaN
# 106    100.000000            NaN
# 115    112.000000            NaN
# 123    120.000000            NaN
# 133    128.266667            NaN
# 134    130.266667            NaN
# 135    131.620833            NaN
# 137    132.620833            NaN
# 140    135.620833            NaN
# 141    135.636806            NaN
# 142    135.636808            NaN
# 143    136.636808            NaN
# 146    138.136808            NaN
# 149    140.136808            NaN
# 150    141.136808            NaN
# 151    141.139122            NaN
# 153    145.139122            NaN
# 156    146.493289            NaN
# 159    148.493289            NaN
# 160    149.847456            NaN
# 162    150.847456            NaN
# ...           ...            ...
# 2117  2041.144541            NaN
# 2121  2049.411208            NaN
# 2122  2051.411208            NaN
# 2125  2052.765374            NaN
# 2126  2053.765374            NaN
# 2127  2056.765374            NaN
# 2128  2066.765374            NaN
# 2129  2066.781346            NaN
# 2130  2066.781348            NaN
# 2131  2067.781348            NaN
# 2133  2069.781348            NaN
# 2134  2071.281348            NaN
# 2135  2073.281348            NaN
# 2136  2074.281348            NaN
# 2137  2074.283663            NaN
# 2140  2078.283663            NaN
# 2143  2079.637830            NaN
# 2144  2081.637830            NaN
# 2145  2082.991997            NaN
# 2146  2083.991997            NaN
# 2149  2086.991997            NaN
# 2150  2087.007969            NaN
# 2151  2087.007971            NaN
# 2154  2088.007971            NaN
# 2155  2089.507971            NaN
# 2157  2091.507971            NaN
# 2160  2092.507971            NaN
# 2161  2092.510286            NaN
# 2165  2096.510286            NaN
# 2166  2097.864452            NaN
#
# [775 rows x 16 columns]

# %% [markdown]
# ### Array cable design and installation

# %%
# Trip data
# project._phases['ArrayCableInstallation'].install_vessel.__dict__
# project._phases.keys()
# project._phases['ArraySystemDesign'].__dict__

project._phases['ArraySystemDesign'].detailed_output
# Out:
# {'array_system': {'cables': {'XLPE_630mm_66kV': {'cable_sections': [(2.957580471,
#       2),
#      (1.6199999999999999, 46),
#      (2.0403069939000003, 2)],
#     'linear_density': 45}}},
#  'array_system_num_strings': 5,
#  'array_system_total_length': 84.5157749298,
#  'array_system_length_by_type': {'XLPE_630mm_66kV': 84.5157749298},
#  'array_system_total_cost': 34397920.3964286,
#  'array_system_cost_by_type': {'XLPE_630mm_66kV': 34397920.3964286}}

# %%
# Installation and capital costs 
ac_time = np.round(project._phases['ArrayCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ac_install_cost = np.round(project._phases['ArrayCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ac_capital_cost = np.round(project._phases['ArraySystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
total_length = np.round(project._phases['ArraySystemDesign'].detailed_output['array_system_length_by_type']['XLPE_630mm_66kV'], 1)

print('Array cable total length: ',total_length , 'km')
print('Array cable install time: ', ac_time, 'days')
print('Array cable install cost: ', ac_install_cost, 'M Euros')
print('Array cable capital cost: ', ac_capital_cost, 'M Euros')
print('Array cable total cost: ', ac_capital_cost + ac_install_cost, 'M Euros')
# Out:
# Array cable total length:  84.5 km
# Array cable install time:  69.6 days
# Array cable install cost:  13.5 M Euros
# Array cable capital cost:  31.6 M Euros
# Array cable total cost:  45.1 M Euros

# %% [markdown]
# ### Export cable

# %%
project._phases['ExportSystemDesign'].detailed_output
# Out:
# {'export_system': {'interconnection_distance': 3,
#   'cable': {'linear_density': 80,
#    'sections': [45.0225],
#    'number': 2,
#    'cable_power': 342.9460597040872}},
#  'export_system_total_mass': 7203.6,
#  'export_system_total_length': 90.045,
#  'export_system_total_cost': 53756865.0,
#  'export_system_cable_power': 342.9460597040872}

# %%
# Installation and capital costs 
ec_time = np.round(project._phases['ExportCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ec_install_cost = np.round(project._phases['ExportCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_capital_cost = np.round(project._phases['ExportSystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ec_total_length = np.round(project._phases['ExportSystemDesign'].detailed_output['export_system_total_length'], 1)

print('Export cable total length: ',ec_total_length , 'km')
print('Export cable install time: ', ec_time, 'days')
print('Export cable install cost: ', ec_install_cost, 'M Euros')
print('Export cable capital cost: ', ec_capital_cost, 'M Euros')
print('Export cable total cost: ', ec_capital_cost + ec_install_cost, 'M Euros')
# Out:
# Export cable total length:  90.0 km
# Export cable install time:  15.7 days
# Export cable install cost:  20.5 M Euros
# Export cable capital cost:  49.5 M Euros
# Export cable total cost:  70.0 M Euros

# %% [markdown]
# ### Offshore substation

# %%
project._phases['OffshoreSubstationDesign'].detailed_output
# proj_df.loc[proj_df['phase']=='OffshoreSubstationInstallation']
# Out:
# {'num_substations': 1,
#  'substation_mpt_rating': 230.0,
#  'substation_topside_mass': 2056.0,
#  'substation_topside_cost': 34312000.0,
#  'substation_substructure_mass': 1159.6541541693207,
#  'substation_substructure_cost': 5898821.846880972}

# %%
# Installation and capital costs 
oss_time = np.round(project._phases['OffshoreSubstationInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
oss_install_cost = np.round(project._phases['OffshoreSubstationInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
oss_capital_cost = np.round(project._phases['OffshoreSubstationDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Offshore substation install time: ', oss_time, 'days')
print('Offshore substation install cost: ', oss_install_cost, 'M Euros')
print('Offshore substation capital cost: ', oss_capital_cost, 'M Euros')
print('Offshore substation total cost: ', oss_capital_cost + oss_install_cost, 'M Euros')
# Out:
# Offshore substation install time:  3.6 days
# Offshore substation install cost:  2.4 M Euros
# Offshore substation capital cost:  59.0 M Euros
# Offshore substation total cost:  61.4 M Euros
