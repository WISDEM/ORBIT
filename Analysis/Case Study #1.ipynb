# %% [markdown]
# ### ORBIT Dudgeon Wind Farm Validation
#
# National Renewable Energy Lab
#
# Matt Shields, Jake Nunemaker
#
# Updated: 1/15/2020

# %%
import os
import sys
import pprint
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as plt_dates

import ORBIT
print(f"Using ORBIT version {ORBIT.__version__}.")
from ORBIT import ProjectManager
# Out:
# Using ORBIT version "0.3.2".

# %% [markdown]
# #### Weather File

# %%
filepath = os.path.join('library', 'weather', 'dudgeon_wave_100m_wind.csv')
weather = pd.read_csv(filepath).set_index(keys='datetime')
weather.describe()
# Out:
#           windspeed    waveheight
# count  20616.000000  20616.000000
# mean       9.138532      1.183350
# std        4.249767      0.667603
# min        0.121744      0.170372
# 25%        5.980583      0.698537
# 50%        8.916669      1.027665
# 75%       11.878717      1.507961
# max       25.680700      5.773216

# %% [markdown]
# #### ORBIT Configuration

# %%
phases = [
    # Substructures
    'MonopileInstallation',
    'ScourProtectionDesign',
    'ScourProtectionInstallation',
    
    # Turbines
    'TurbineInstallation',
    
    # Electrical
    'ArraySystemDesign',
    'ArrayCableInstallation',
    'ExportSystemDesign',
    'ExportCableInstallation',
    'OffshoreSubstationInstallation'
]

required_config = ProjectManager.compile_input_dict(phases)
# required_config

# %%
config = {
    # Substations
    "num_substations": 1,
    
    # Vessels
    'scour_protection_install_vessel': 'ExampleScour',
    'trench_dig_vessel': 'StematSpirit',
    'array_cable_lay_vessel': 'Ndeavor',
    'export_cable_lay_vessel': 'StematSpirit',
    "oss_install_vessel": "OlegStrashnov",  # Actually vessel from SPT Offshore
    
    # Site/plant
    'site': {
        'depth': 22.5,
        'distance': 124,
        'distance_to_landfall': 35,
        'distance_to_beach': 0,
        'distance_to_interconnection': 3,
        'mean_windspeed': 9.13
    },
    
    'plant': {
        'layout': 'grid',
        'num_turbines': 67,
        'row_spacing': 7,
        'turbine_spacing': 1070 / 154,
        'substation_distance': 1
    },
    
    'port': {
        'num_cranes': 1,
        'monthly_rate': 2000000,
        "name": "Green Port"
    },
    
    # Turbine + components
    'turbine': '8MW_generic',

    # Substructure components
    'substructure': {'diameter': 7.2},
    'monopile': {
        'type': 'Monopile',
        'length': 69,
        'diameter': 7.2,
        'deck_space': 496.8,
        'weight': 800
    },
    
    'transition_piece': {
        'type': 'Transition Piece',
        'deck_space': 100,
        'weight': 400
    },
    
    'scour_protection_design': {
        'cost_per_tonne': 40,
    },
    
    # Electrical
    'array_system_design': {
        'cables': ['XLPE_185mm_33kV', 'XLPE_500mm_33kV']
    },
    
    'array_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system_design': {
        'cables': 'XLPE_500mm_132kV',
        'percent_added_length': .2
    },
    
#     "offshore_substation_topside": {
#         "type": "Topside",
#         "deck_space": 200,
#         "weight": 2000,
#     },
#     "offshore_substation_substructure": {
#         "type": "Monopile",
#         "deck_space": 500,
#         "weight": 1850,
#         "length": 69,  # Assumed to be the same as monopile length
#     },


    # Phase specific configurations
    'MonopileInstallation': {
        'wtiv': 'Benchmarking_WTIV_monopile',  
        
    },
    
    'TurbineInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine'
    },
    
    'OffshoreSubstationInstallation': {
        "num_feeders": 1,
        "feeder": "seajacks_scylla",
    },    
    
    # Phases
    'design_phases': [
#         "MonopileDesign",
#         'ScourProtectionDesign',
#         'ArraySystemDesign',
#         'ExportSystemDesign',
#         'OffshoreSubstationDesign'
    ],
    
    'install_phases': {
        'MonopileInstallation': '07/01/2016',         # Updated dates 
#         'ScourProtectionInstallation': '09/01/2016',  # Placed at the end of the monopile installation
        'TurbineInstallation': '07/01/2016',
#         'ArrayCableInstallation': '06/29/2016',
#         'ExportCableInstallation': '03/17/2016',
#         'OffshoreSubstationInstallation': '08/01/2016'
    }
}

# %%
path = os.path.join(os.getcwd(), "library")
project = ProjectManager(config, weather=weather, library_path=path)
# Out:
# ORBIT library intialized at 'C:\Users\mshields\Documents\Analysis Tools\NREL\ORBIT\ORBIT-dev\dudgeon\library'

# %%
project.run_project()

# %%
# project._phases['TurbineInstallation'].wtiv.trip_data
project.project_dataframe.loc[(project.project_dataframe['phase']=='MonopileInstallation')]
# Out:
#                     action       agent          cost    duration level  \
# 8               FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 9               FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 10              FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 11              FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 12              FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 13              FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 14              FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 15              FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 16              FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 17              FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 18              FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 19              FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 20                 Transit        WTIV  1.033333e+05    4.960000  INFO
# 21          PositionOnsite        WTIV  4.166667e+04    2.000000  INFO
# 22                  Jackup        WTIV  1.128484e-01    0.000005  INFO
# 24               RovSurvey        WTIV  2.083333e+04    1.000000  INFO
# 27         ReleaseMonopile        WTIV  6.250000e+04    3.000000  INFO
# 28           UpendMonopile        WTIV  3.327546e+02    0.015972  INFO
# 29           LowerMonopile        WTIV  4.186225e-02    0.000002  INFO
# 30            CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 31           DriveMonopile        WTIV  3.125000e+04    1.500000  INFO
# 32               ReleaseTP        WTIV  4.166667e+04    2.000000  INFO
# 34            CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 35    LowerTransitionPiece        WTIV  4.822531e+01    0.002315  INFO
# 36     BoltTransitionPiece        WTIV  8.333333e+04    4.000000  INFO
# 37                Jackdown        WTIV  1.128484e-01    0.000005  INFO
# 40          PositionOnsite        WTIV  4.166667e+04    2.000000  INFO
# 41                  Jackup        WTIV  1.128484e-01    0.000005  INFO
# 43               RovSurvey        WTIV  2.083333e+04    1.000000  INFO
# 44         ReleaseMonopile        WTIV  6.250000e+04    3.000000  INFO
# ...                    ...         ...           ...         ...   ...
# 1090                Jackup        WTIV  1.128484e-01    0.000005  INFO
# 1091             RovSurvey        WTIV  2.083333e+04    1.000000  INFO
# 1093       ReleaseMonopile        WTIV  6.250000e+04    3.000000  INFO
# 1094         UpendMonopile        WTIV  3.327546e+02    0.015972  INFO
# 1095         LowerMonopile        WTIV  4.186225e-02    0.000002  INFO
# 1096          CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 1097         DriveMonopile        WTIV  3.125000e+04    1.500000  INFO
# 1100             ReleaseTP        WTIV  4.166667e+04    2.000000  INFO
# 1101          CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 1102  LowerTransitionPiece        WTIV  4.822531e+01    0.002315  INFO
# 1104   BoltTransitionPiece        WTIV  8.333333e+04    4.000000  INFO
# 1105              Jackdown        WTIV  1.128484e-01    0.000005  INFO
# 1107               Transit        WTIV  1.033333e+05    4.960000  INFO
# 1112            FastenItem        WTIV  2.500000e+05   12.000000  INFO
# 1114            FastenItem        WTIV  1.666667e+05    8.000000  INFO
# 1117               Transit        WTIV  1.033333e+05    4.960000  INFO
# 1120        PositionOnsite        WTIV  4.166667e+04    2.000000  INFO
# 1121                Jackup        WTIV  1.128484e-01    0.000005  INFO
# 1122             RovSurvey        WTIV  2.083333e+04    1.000000  INFO
# 1123       ReleaseMonopile        WTIV  6.250000e+04    3.000000  INFO
# 1124         UpendMonopile        WTIV  3.327546e+02    0.015972  INFO
# 1125         LowerMonopile        WTIV  4.186225e-02    0.000002  INFO
# 1127          CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 1128         DriveMonopile        WTIV  3.125000e+04    1.500000  INFO
# 1129             ReleaseTP        WTIV  4.166667e+04    2.000000  INFO
# 1130          CraneReequip        WTIV  2.083333e+04    1.000000  INFO
# 1131  LowerTransitionPiece        WTIV  4.822531e+01    0.002315  INFO
# 1135   BoltTransitionPiece        WTIV  8.333333e+04    4.000000  INFO
# 1136              Jackdown        WTIV  1.128484e-01    0.000005  INFO
# 1137            PortRental  Green Port  1.133715e+06  413.806092  INFO
#
#      location  message                 phase            target         time  \
# 8        Port      NaN  MonopileInstallation          Monopile    84.000000
# 9        Port      NaN  MonopileInstallation  Transition Piece    92.000000
# 10       Port      NaN  MonopileInstallation          Monopile   104.000000
# 11       Port      NaN  MonopileInstallation  Transition Piece   112.000000
# 12       Port      NaN  MonopileInstallation          Monopile   124.000000
# 13       Port      NaN  MonopileInstallation  Transition Piece   132.000000
# 14       Port      NaN  MonopileInstallation          Monopile   144.000000
# 15       Port      NaN  MonopileInstallation  Transition Piece   152.000000
# 16       Port      NaN  MonopileInstallation          Monopile   164.000000
# 17       Port      NaN  MonopileInstallation  Transition Piece   172.000000
# 18       Port      NaN  MonopileInstallation          Monopile   184.000000
# 19       Port      NaN  MonopileInstallation  Transition Piece   192.000000
# 20     At Sea      NaN  MonopileInstallation               NaN   196.960000
# 21       Site      NaN  MonopileInstallation               NaN   198.960000
# 22       Site      NaN  MonopileInstallation               NaN   198.960005
# 24       Site      NaN  MonopileInstallation               NaN   199.960005
# 27       Site      NaN  MonopileInstallation               NaN   202.960005
# 28       Stie      NaN  MonopileInstallation               NaN   202.975978
# 29       Site      NaN  MonopileInstallation               NaN   202.975980
# 30       Site      NaN  MonopileInstallation               NaN   203.975980
# 31       Site      NaN  MonopileInstallation               NaN   205.475980
# 32       Site      NaN  MonopileInstallation               NaN   207.475980
# 34       Site      NaN  MonopileInstallation               NaN   208.475980
# 35       Site      NaN  MonopileInstallation               NaN   208.478294
# 36       Site      NaN  MonopileInstallation               NaN   212.478294
# 37       Site      NaN  MonopileInstallation               NaN   212.478300
# 40       Site      NaN  MonopileInstallation               NaN   214.478300
# 41       Site      NaN  MonopileInstallation               NaN   214.478305
# 43       Site      NaN  MonopileInstallation               NaN   215.478305
# 44       Site      NaN  MonopileInstallation               NaN   218.478305
# ...       ...      ...                   ...               ...          ...
# 1090     Site      NaN  MonopileInstallation               NaN  2616.849498
# 1091     Site      NaN  MonopileInstallation               NaN  2617.849498
# 1093     Site      NaN  MonopileInstallation               NaN  2620.849498
# 1094     Stie      NaN  MonopileInstallation               NaN  2620.865470
# 1095     Site      NaN  MonopileInstallation               NaN  2620.865472
# 1096     Site      NaN  MonopileInstallation               NaN  2621.865472
# 1097     Site      NaN  MonopileInstallation               NaN  2623.365472
# 1100     Site      NaN  MonopileInstallation               NaN  2625.365472
# 1101     Site      NaN  MonopileInstallation               NaN  2626.365472
# 1102     Site      NaN  MonopileInstallation               NaN  2626.367787
# 1104     Site      NaN  MonopileInstallation               NaN  2630.367787
# 1105     Site      NaN  MonopileInstallation               NaN  2630.367792
# 1107   At Sea      NaN  MonopileInstallation               NaN  2635.327792
# 1112     Port      NaN  MonopileInstallation          Monopile  2647.327792
# 1114     Port      NaN  MonopileInstallation  Transition Piece  2655.327792
# 1117   At Sea      NaN  MonopileInstallation               NaN  2660.287792
# 1120     Site      NaN  MonopileInstallation               NaN  2662.287792
# 1121     Site      NaN  MonopileInstallation               NaN  2662.287797
# 1122     Site      NaN  MonopileInstallation               NaN  2663.287797
# 1123     Site      NaN  MonopileInstallation               NaN  2666.287797
# 1124     Stie      NaN  MonopileInstallation               NaN  2666.303770
# 1125     Site      NaN  MonopileInstallation               NaN  2666.303772
# 1127     Site      NaN  MonopileInstallation               NaN  2667.303772
# 1128     Site      NaN  MonopileInstallation               NaN  2668.803772
# 1129     Site      NaN  MonopileInstallation               NaN  2670.803772
# 1130     Site      NaN  MonopileInstallation               NaN  2671.803772
# 1131     Site      NaN  MonopileInstallation               NaN  2671.806087
# 1135     Site      NaN  MonopileInstallation               NaN  2675.806087
# 1136     Site      NaN  MonopileInstallation               NaN  2675.806092
# 1137     Port      NaN  MonopileInstallation               NaN  2675.806092
#
#             type
# 8     Operations
# 9     Operations
# 10    Operations
# 11    Operations
# 12    Operations
# 13    Operations
# 14    Operations
# 15    Operations
# 16    Operations
# 17    Operations
# 18    Operations
# 19    Operations
# 20    Operations
# 21    Operations
# 22    Operations
# 24    Operations
# 27    Operations
# 28    Operations
# 29    Operations
# 30    Operations
# 31    Operations
# 32    Operations
# 34    Operations
# 35    Operations
# 36    Operations
# 37    Operations
# 40    Operations
# 41    Operations
# 43    Operations
# 44    Operations
# ...          ...
# 1090  Operations
# 1091  Operations
# 1093  Operations
# 1094  Operations
# 1095  Operations
# 1096  Operations
# 1097  Operations
# 1100  Operations
# 1101  Operations
# 1102  Operations
# 1104  Operations
# 1105  Operations
# 1107  Operations
# 1112  Operations
# 1114  Operations
# 1117  Operations
# 1120  Operations
# 1121  Operations
# 1122  Operations
# 1123  Operations
# 1124  Operations
# 1125  Operations
# 1127  Operations
# 1128  Operations
# 1129  Operations
# 1130  Operations
# 1131  Operations
# 1135  Operations
# 1136  Operations
# 1137  Operations
#
# [1038 rows x 11 columns]

# %% [markdown]
# ### Results
# #### Array System Design

# %%
project._phases["ArraySystemDesign"].total_cable_length_by_type

# %%
project._phases['ArraySystemDesign'].num_full_strings

# %%
project._phases['ArraySystemDesign'].num_partial_strings

# %%
# Module outputs
project._phases['ArraySystemDesign'].total_phase_cost

# %%
total = sum([v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()])
print(f"Total length: {total}")

# %%
cables = project._phases['ArraySystemDesign'].cables

total_mass = sum([
    cables[k].linear_density*v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()
])
total_mass

# %% [markdown]
# #### Export System Design

# %%
project._phases['ExportSystemDesign'].total_mass

# %%
project._phases['ExportSystemDesign'].num_cables

# %%
project._phases['ExportSystemDesign'].cable.cable_power

# %%
project._phases['ExportSystemDesign']._plant_capacity

# %%
project._phases['ExportSystemDesign'].total_phase_cost * 2/3

# %%
project._phases['ExportSystemDesign'].total_length*2/3

# %% [markdown]
# #### Offshore Substation Design

# %%
project._phases["OffshoreSubstationDesign"].total_phase_cost

# %%
project._phases["OffshoreSubstationDesign"].design_result

# %% [markdown]
# #### Monopile Design

# %%
# config['monopile']['weight'] * config['plant']['num_turbines'] * 3000 <<<<------ OLD

# %%
project._phases["MonopileDesign"].total_phase_cost # <<<---- NEW

# %%
project._phases["MonopileDesign"].design_result

# %% [markdown]
# #### Scour Protection Design

# %%
project._phases['ScourProtectionDesign'].design_result  # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionDesign'].protection_depth

# %%
project._phases['ScourProtectionDesign'].total_phase_cost # <---- NEW

# %% [markdown]
# #### Monopile Installation

# %%
project._phases['MonopileInstallation'].total_phase_time / (8760 / 12)

# %%
project._phases['MonopileInstallation'].total_phase_cost

# %%
project._phases['MonopileInstallation'].detailed_output

# %%
project._phases['MonopileInstallation'].total_phase_time / 67

# %%
mi = project.project_dataframe.loc[project.project_dataframe['phase']=='MonopileInstallation']

mi.groupby('action').sum()['duration']

# %% [markdown]
# #### Scour Protection Installation

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / (8760 / 12) # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].total_phase_cost # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].detailed_output

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / 67  # <--- NEW, revised protection depth

# %%
spi = project.project_dataframe.loc[project.project_dataframe['phase']=='ScourProtectionInstallation']

spi.groupby('action').sum()['duration']

# %% [markdown]
# #### Turbine Installation

# %%
project._phases['TurbineInstallation'].total_phase_time / (8760 / 12)  # NEW, turbine installation revised to eliminate too many crane reequips between blade installations

# %%
project._phases['TurbineInstallation'].total_phase_cost  # NEW, see above

# %%
project._phases['TurbineInstallation'].detailed_output

# %%
project._phases['TurbineInstallation'].total_phase_time / 67  # NEW, see above

# %%
ti = project.project_dataframe.loc[project.project_dataframe['phase']=='TurbineInstallation']

ti.groupby('action').sum()['duration']

# %%
project._phases['TurbineInstallation'].wtiv.trip_data

# %% [markdown]
# #### Array System Installation

# %%
project._phases['ArrayCableInstallation'].total_phase_time / (8760 / 12)  # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ArrayCableInstallation'].total_phase_cost

# %%
project._phases['ArrayCableInstallation'].detailed_output

# %%
asi = project.project_dataframe.loc[project.project_dataframe['phase']=='ArrayCableInstallation']

asi.groupby('action').sum()['duration']

# %% [markdown]
# #### Export System Installation

# %%
project._phases['ExportCableInstallation'].total_phase_time # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].total_phase_cost # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].detailed_output

# %%
esi = project.project_dataframe.loc[project.project_dataframe['phase']=='ExportCableInstallation']

esi.groupby('action').sum()['duration']

# %% [markdown]
# #### Offshore Substation Installation

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_time / (24)

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_cost

# %%
project._phases['OffshoreSubstationInstallation'].detailed_output

# %%
osi = project.project_dataframe.loc[project.project_dataframe['phase']=='OffshoreSubstationInstallation']

osi.groupby('action').sum()['duration']

# %%
project.project_dataframe["phase"].unique()

# %%
project.design_results

# %%
project.project_dataframe.time.max() / (8760 / 12)

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_costs).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Cost ($USD)')

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_times).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Time (h)')

# %%
phases = project.phase_dates.keys()
_start_dates = [project.phase_dates[p]['start'] for p in phases]
start_floats = [plt_dates.datestr2num(i) for i in _start_dates]
_end_dates = [project.phase_dates[p]['end'] for p in phases]
end_floats = [plt_dates.datestr2num(i) for i in _end_dates]

# %%
data = pd.DataFrame(columns=phases, data=[start_floats, end_floats], index=['Start', 'End']).T
data = data.reset_index().rename(columns={'index': 'Phase'})
data['Type'] = 'Model'

validation_data = data.copy()
validation_data = validation_data.set_index(keys='Phase')
validation_data.loc['MonopileInstallation', 'End'] = plt_dates.datestr2num("08/03/16 00:00")
validation_data.loc['ScourProtectionInstallation', 'End'] = plt_dates.datestr2num("09/30/16 00:00")
validation_data.loc['TurbineInstallation', 'End'] = plt_dates.datestr2num("09/04/17 00:00")
validation_data.loc['ArrayCableInstallation', 'End'] = plt_dates.datestr2num("08/27/16 00:00")
validation_data.loc['ExportCableInstallation', 'End'] = plt_dates.datestr2num("04/21/16 00:00")
validation_data['Type'] = 'Dudgeon'
validation_data = validation_data.reset_index().rename(columns={'index': 'Phase'})

data = pd.concat([data, validation_data])
data['Time'] = data['End'] - data['Start']
data

# %%
import seaborn as sns
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='Phase', y='Time', hue='Type', data=data, ax=axis)

for tick in axis.get_xticklabels():
    tick.set_rotation(90)
    
# axis.yaxis_date()
# fig.autofmt_xdate()

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='End', y='Phase', data=data, ax=axis, zorder=3, hue='Type')
axis = sns.barplot(x='Start', y='Phase', data=data, ax=axis, palette={'Model': 'w', 'Dudgeon': 'w'}, zorder=5, hue='Type')

axis.set_xlim(data['Start'].min()-10, data['End'].max()+10)

# Legend
handles, labels = axis.get_legend_handles_labels()
axis.legend(handles[:2], labels[:2], fontsize=8)

# Formatting
axis.set_xlabel('')
# axis.grid(axis='x', which='major', lw=0.5, zorder=4)
# Tick parameters
axis.tick_params(axis='both', labelsize=8, width=0.5, length=3)

# Plot formatting
for ax in ['top', 'bottom', 'left', 'right']:
    axis.spines[ax].set_linewidth(0.5)
    axis.spines[ax].set_zorder(20)

axis.xaxis_date()
fig.autofmt_xdate()
