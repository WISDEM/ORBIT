# %% [markdown]
# ### Cost model benchmarking - case study #1
#
# Loosely based on Dudgeon Wind Farm (400 MW, 8MW turbines)
#
# National Renewable Energy Lab
#
# Matt Shields, Jake Nunemaker
#
# Updated: 2/17/2020

# %%
import os
import sys
import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as plt_dates

import ORBIT
print(f"Using ORBIT version {ORBIT.__version__}.")
from ORBIT import ProjectManager


usd_to_euro = 0.92
# Out:
# Using ORBIT version 0+unknown.

# %% [markdown]
# #### Weather File

# %%
filepath = os.path.join('library', 'weather', 'dudgeon_wave_100m_wind.csv')
weather = pd.read_csv(filepath).set_index(keys='datetime')
weather.describe()
# Out:
#           windspeed    waveheight
# count  20616.000000  20616.000000
# mean       9.138532      1.183350
# std        4.249767      0.667603
# min        0.121744      0.170372
# 25%        5.980583      0.698537
# 50%        8.916669      1.027665
# 75%       11.878717      1.507961
# max       25.680700      5.773216

# %% [markdown]
# #### ORBIT Configuration

# %%
phases = [
    # Substructures
    'MonopileInstallation',
#     'ScourProtectionDesign',
#     'ScourProtectionInstallation',
    
    # Turbines
    'TurbineInstallation',
    
#     # Electrical
    'ArraySystemDesign',
    'ArrayCableInstallation',
#     'ExportSystemDesign',
#     'ExportCableInstallation',
#     'OffshoreSubstationInstallation'
]

required_config = ProjectManager.compile_input_dict(phases)
# required_config

# %%
config = {
    # Substations
#     "num_substations": 1,
    
    # Vessels
#     'scour_protection_install_vessel': 'ExampleScour',
#     'trench_dig_vessel': 'StematSpirit',
#     'array_cable_lay_vessel': 'cable_lay_vessel',
#     'export_cable_lay_vessel': 'StematSpirit',
#     "oss_install_vessel": "OlegStrashnov",  # Actually vessel from SPT Offshore
    
    # Site/plant
    'site': {
        'depth': 22.5,
        'distance': 124,
        'distance_to_landfall': 42,
        'distance_to_beach': 0,
        'distance_to_interconnection': 3,
        'mean_windspeed': 9.13
    },
    
    'plant': {
        'layout': 'grid',
        'num_turbines': 50,
        'row_spacing': 7,
        'turbine_spacing': 9,
        'substation_distance': 1
    },
    
    'port': {
        'num_cranes': 1,
        'monthly_rate': 2000000,
        "name": "Green Port"
    },
    
    # Turbine + components
    'turbine': '8MW_generic',

    # Substructure components
    'substructure': {'diameter': 7.2},
    'monopile': {
        'type': 'Monopile',
        'length': 69,
        'diameter': 7.2,
        'deck_space': 496.8,
        'weight': 800,
        'monopile_steel_cost' : 2000 / usd_to_euro,
    },
    
    'transition_piece': {
        'type': 'Transition Piece',
        'deck_space': 100,
        'weight': 400,
        'transition_piece_steel_cost' : 2000 / usd_to_euro,
    },
    
#     'scour_protection_design': {
#         'cost_per_tonne': 40,
#     },
    
    # Electrical
    'array_system_design': {
        'cables': 'XLPE_630mm_66kV'
    },
    
    'array_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system': {
        'strategy': 'lay_bury'
    },
    
    'export_system_design': {
        'cables': 'XLPE_500mm_132kV',
        'percent_added_length': 0
    },
    
#     "offshore_substation_topside": {
#         "type": "Topside",
#         "deck_space": 200,
#         "weight": 2000,
#     },
#     "offshore_substation_substructure": {
#         "type": "Monopile",
#         "deck_space": 500,
#         "weight": 1850,
#         "length": 69,  # Assumed to be the same as monopile length
#     },


    # Phase specific configurations
    'MonopileInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine',  
        
    },
    
    'TurbineInstallation': {
        'wtiv': 'Benchmarking_WTIV_turbine'
    },
    
    'ArrayCableInstallation': {
        'array_cable_install_vessel' : 'cable_lay_vessel'
    },
    
#     'OffshoreSubstationInstallation': {
#         "num_feeders": 1,
#         "feeder": "seajacks_scylla",
#     },    
    
    # Phases
    'design_phases': [
#         "MonopileDesign",
#         'ScourProtectionDesign',
        'ArraySystemDesign',
#         'ExportSystemDesign',
#         'OffshoreSubstationDesign'
    ],
    
    'install_phases': {
        'MonopileInstallation': '07/01/2016',         # Updated dates 
#         'ScourProtectionInstallation': '09/01/2016',  # Placed at the end of the monopile installation
        'TurbineInstallation': '07/01/2016',
        'ArrayCableInstallation': '07/01/2016',
#         'ExportCableInstallation': '03/17/2016',
#         'OffshoreSubstationInstallation': '08/01/2016'
    }
}

# %%
path = os.path.join(os.getcwd(), "library")
project = ProjectManager(config, weather=weather, library_path=path)
# Out:
# ORBIT library intialized at 'C:\Users\mshields\Documents\Analysis Tools\NREL\ORBIT\Analysis\library'

# %%
project.run_project()

# %% [markdown]
# # Results
#
# ### Turbine installation

# %%
# Trip data
project._phases['TurbineInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=3012, deck_space=3884, items={TowerSection: 8, Nacelle: 4, Blade: 12}),
#  Trip(cargo_weight=1506, deck_space=1942, items={TowerSection: 4, Nacelle: 2, Blade: 6})]

# %%
# Installation costs 
turb_time = np.round(project._phases['TurbineInstallation'].total_phase_time * (1/24) ,1 ) # Convert hours to days
turb_cost = np.round(project._phases['TurbineInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)

print('Turbine install time: ', turb_time, 'days')
print('Turbine install cost: ', turb_cost, 'M Euros')
# Out:
# Turbine install time:  149.1 days
# Turbine install cost:  39.2 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='TurbineInstallation']
# Out:
#                      action agent  cable_lay_speed           cost  \
# 1                  Mobilize  WTIV              NaN  752500.000000
# 3      Fasten Tower Section  WTIV              NaN   35833.333333
# 5      Fasten Tower Section  WTIV              NaN   35833.333333
# 7            Fasten Nacelle  WTIV              NaN   35833.333333
# 9              Fasten Blade  WTIV              NaN   13437.500000
# 11             Fasten Blade  WTIV              NaN   13437.500000
# 13             Fasten Blade  WTIV              NaN   13437.500000
# 15     Fasten Tower Section  WTIV              NaN   35833.333333
# 17     Fasten Tower Section  WTIV              NaN   35833.333333
# 20           Fasten Nacelle  WTIV              NaN   35833.333333
# 21             Fasten Blade  WTIV              NaN   13437.500000
# 22             Fasten Blade  WTIV              NaN   13437.500000
# 24             Fasten Blade  WTIV              NaN   13437.500000
# 25     Fasten Tower Section  WTIV              NaN   35833.333333
# 29     Fasten Tower Section  WTIV              NaN   35833.333333
# 31           Fasten Nacelle  WTIV              NaN   35833.333333
# 32             Fasten Blade  WTIV              NaN   13437.500000
# 33             Fasten Blade  WTIV              NaN   13437.500000
# 35             Fasten Blade  WTIV              NaN   13437.500000
# 39     Fasten Tower Section  WTIV              NaN   35833.333333
# 40     Fasten Tower Section  WTIV              NaN   35833.333333
# 43           Fasten Nacelle  WTIV              NaN   35833.333333
# 44             Fasten Blade  WTIV              NaN   13437.500000
# 47             Fasten Blade  WTIV              NaN   13437.500000
# 48             Fasten Blade  WTIV              NaN   13437.500000
# 51                  Transit  WTIV              NaN   74055.555556
# 53          Position Onsite  WTIV              NaN   17916.666667
# 54                   Jackup  WTIV              NaN   12131.076389
# 57    Release Tower Section  WTIV              NaN   26875.000000
# 58       Lift Tower Section  WTIV              NaN     118.200231
# ...                     ...   ...              ...            ...
# 2698          Release Blade  WTIV              NaN    8958.333333
# 2699             Lift Blade  WTIV              NaN     234.326775
# 2700           Attach Blade  WTIV              NaN   31354.166667
# 2701          Release Blade  WTIV              NaN    8958.333333
# 2702             Lift Blade  WTIV              NaN     234.326775
# 2703           Attach Blade  WTIV              NaN   31354.166667
# 2704               Jackdown  WTIV              NaN   12131.076389
# 2705        Position Onsite  WTIV              NaN   17916.666667
# 2706                 Jackup  WTIV              NaN   12131.076389
# 2707  Release Tower Section  WTIV              NaN   26875.000000
# 2708     Lift Tower Section  WTIV              NaN     118.200231
# 2709   Attach Tower Section  WTIV              NaN   53750.000000
# 2710  Release Tower Section  WTIV              NaN   26875.000000
# 2711     Lift Tower Section  WTIV              NaN     236.400463
# 2712   Attach Tower Section  WTIV              NaN   53750.000000
# 2713        Release Nacelle  WTIV              NaN   26875.000000
# 2714                Reequip  WTIV              NaN    8958.333333
# 2715           Lift Nacelle  WTIV              NaN     234.326775
# 2716         Attach Nacelle  WTIV              NaN   53750.000000
# 2717                Reequip  WTIV              NaN    8958.333333
# 2718          Release Blade  WTIV              NaN    8958.333333
# 2719             Lift Blade  WTIV              NaN     234.326775
# 2720           Attach Blade  WTIV              NaN   31354.166667
# 2721          Release Blade  WTIV              NaN    8958.333333
# 2722             Lift Blade  WTIV              NaN     234.326775
# 2723           Attach Blade  WTIV              NaN   31354.166667
# 2724          Release Blade  WTIV              NaN    8958.333333
# 2725             Lift Blade  WTIV              NaN     234.326775
# 2726           Attach Blade  WTIV              NaN   31354.166667
# 2727               Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier    duration  hub_height   level  max_waveheight  \
# 1                 0.5  168.000000         NaN  ACTION             NaN
# 3                 NaN    4.000000       113.0  ACTION             NaN
# 5                 NaN    4.000000       113.0  ACTION             NaN
# 7                 NaN    4.000000       113.0  ACTION             NaN
# 9                 NaN    1.500000       113.0  ACTION             NaN
# 11                NaN    1.500000       113.0  ACTION             NaN
# 13                NaN    1.500000       113.0  ACTION             NaN
# 15                NaN    4.000000       113.0  ACTION             NaN
# 17                NaN    4.000000       113.0  ACTION             NaN
# 20                NaN    4.000000       113.0  ACTION             NaN
# 21                NaN    1.500000       113.0  ACTION             NaN
# 22                NaN    1.500000       113.0  ACTION             NaN
# 24                NaN    1.500000       113.0  ACTION             NaN
# 25                NaN    4.000000       113.0  ACTION             NaN
# 29                NaN    4.000000       113.0  ACTION             NaN
# 31                NaN    4.000000       113.0  ACTION             NaN
# 32                NaN    1.500000       113.0  ACTION             NaN
# 33                NaN    1.500000       113.0  ACTION             NaN
# 35                NaN    1.500000       113.0  ACTION             NaN
# 39                NaN    4.000000       113.0  ACTION             NaN
# 40                NaN    4.000000       113.0  ACTION             NaN
# 43                NaN    4.000000       113.0  ACTION             NaN
# 44                NaN    1.500000       113.0  ACTION             NaN
# 47                NaN    1.500000       113.0  ACTION             NaN
# 48                NaN    1.500000       113.0  ACTION             NaN
# 51                NaN    8.266667         NaN  ACTION             NaN
# 53                NaN    2.000000         NaN  ACTION             NaN
# 54                NaN    1.354167       113.0  ACTION             NaN
# 57                NaN    3.000000         NaN  ACTION             NaN
# 58                NaN    0.013194       113.0  ACTION             NaN
# ...               ...         ...         ...     ...             ...
# 2698              NaN    1.000000         NaN  ACTION             NaN
# 2699              NaN    0.026157       113.0  ACTION             NaN
# 2700              NaN    3.500000       113.0  ACTION             NaN
# 2701              NaN    1.000000         NaN  ACTION             NaN
# 2702              NaN    0.026157       113.0  ACTION             NaN
# 2703              NaN    3.500000       113.0  ACTION             NaN
# 2704              NaN    1.354167         NaN  ACTION             NaN
# 2705              NaN    2.000000         NaN  ACTION             NaN
# 2706              NaN    1.354167       113.0  ACTION             NaN
# 2707              NaN    3.000000         NaN  ACTION             NaN
# 2708              NaN    0.013194       113.0  ACTION             NaN
# 2709              NaN    6.000000       113.0  ACTION             NaN
# 2710              NaN    3.000000         NaN  ACTION             NaN
# 2711              NaN    0.026389       113.0  ACTION             NaN
# 2712              NaN    6.000000       113.0  ACTION             NaN
# 2713              NaN    3.000000         NaN  ACTION             NaN
# 2714              NaN    1.000000         NaN  ACTION             NaN
# 2715              NaN    0.026157       113.0  ACTION             NaN
# 2716              NaN    6.000000       113.0  ACTION             NaN
# 2717              NaN    1.000000         NaN  ACTION             NaN
# 2718              NaN    1.000000         NaN  ACTION             NaN
# 2719              NaN    0.026157       113.0  ACTION             NaN
# 2720              NaN    3.500000       113.0  ACTION             NaN
# 2721              NaN    1.000000         NaN  ACTION             NaN
# 2722              NaN    0.026157       113.0  ACTION             NaN
# 2723              NaN    3.500000       113.0  ACTION             NaN
# 2724              NaN    1.000000         NaN  ACTION             NaN
# 2725              NaN    0.026157       113.0  ACTION             NaN
# 2726              NaN    3.500000       113.0  ACTION             NaN
# 2727              NaN    1.354167         NaN  ACTION             NaN
#
#       max_windspeed                phase           phase_name  site_depth  \
# 1               NaN  TurbineInstallation                  NaN         NaN
# 3               NaN  TurbineInstallation  TurbineInstallation        22.5
# 5               NaN  TurbineInstallation  TurbineInstallation        22.5
# 7               NaN  TurbineInstallation  TurbineInstallation        22.5
# 9               NaN  TurbineInstallation  TurbineInstallation        22.5
# 11              NaN  TurbineInstallation  TurbineInstallation        22.5
# 13              NaN  TurbineInstallation  TurbineInstallation        22.5
# 15              NaN  TurbineInstallation  TurbineInstallation        22.5
# 17              NaN  TurbineInstallation  TurbineInstallation        22.5
# 20              NaN  TurbineInstallation  TurbineInstallation        22.5
# 21              NaN  TurbineInstallation  TurbineInstallation        22.5
# 22              NaN  TurbineInstallation  TurbineInstallation        22.5
# 24              NaN  TurbineInstallation  TurbineInstallation        22.5
# 25              NaN  TurbineInstallation  TurbineInstallation        22.5
# 29              NaN  TurbineInstallation  TurbineInstallation        22.5
# 31              NaN  TurbineInstallation  TurbineInstallation        22.5
# 32              NaN  TurbineInstallation  TurbineInstallation        22.5
# 33              NaN  TurbineInstallation  TurbineInstallation        22.5
# 35              NaN  TurbineInstallation  TurbineInstallation        22.5
# 39              NaN  TurbineInstallation  TurbineInstallation        22.5
# 40              NaN  TurbineInstallation  TurbineInstallation        22.5
# 43              NaN  TurbineInstallation  TurbineInstallation        22.5
# 44              NaN  TurbineInstallation  TurbineInstallation        22.5
# 47              NaN  TurbineInstallation  TurbineInstallation        22.5
# 48              NaN  TurbineInstallation  TurbineInstallation        22.5
# 51              NaN  TurbineInstallation                  NaN         NaN
# 53              NaN  TurbineInstallation                  NaN         NaN
# 54              NaN  TurbineInstallation  TurbineInstallation        22.5
# 57              NaN  TurbineInstallation                  NaN         NaN
# 58              NaN  TurbineInstallation  TurbineInstallation        22.5
# ...             ...                  ...                  ...         ...
# 2698            NaN  TurbineInstallation                  NaN         NaN
# 2699            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2700            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2701            NaN  TurbineInstallation                  NaN         NaN
# 2702            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2703            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2704            NaN  TurbineInstallation                  NaN         NaN
# 2705            NaN  TurbineInstallation                  NaN         NaN
# 2706            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2707            NaN  TurbineInstallation                  NaN         NaN
# 2708            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2709            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2710            NaN  TurbineInstallation                  NaN         NaN
# 2711            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2712            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2713            NaN  TurbineInstallation                  NaN         NaN
# 2714            NaN  TurbineInstallation                  NaN         NaN
# 2715            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2716            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2717            NaN  TurbineInstallation                  NaN         NaN
# 2718            NaN  TurbineInstallation                  NaN         NaN
# 2719            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2720            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2721            NaN  TurbineInstallation                  NaN         NaN
# 2722            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2723            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2724            NaN  TurbineInstallation                  NaN         NaN
# 2725            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2726            NaN  TurbineInstallation  TurbineInstallation        22.5
# 2727            NaN  TurbineInstallation                  NaN         NaN
#
#              time  transit_speed
# 1        0.000000            NaN
# 3        4.000000            NaN
# 5        8.000000            NaN
# 7       12.000000            NaN
# 9       13.500000            NaN
# 11      15.000000            NaN
# 13      16.500000            NaN
# 15      20.500000            NaN
# 17      24.500000            NaN
# 20      28.500000            NaN
# 21      30.000000            NaN
# 22      31.500000            NaN
# 24      33.000000            NaN
# 25      37.000000            NaN
# 29      41.000000            NaN
# 31      45.000000            NaN
# 32      46.500000            NaN
# 33      48.000000            NaN
# 35      49.500000            NaN
# 39      53.500000            NaN
# 40      57.500000            NaN
# 43      61.500000            NaN
# 44      63.000000            NaN
# 47      64.500000            NaN
# 48      66.000000            NaN
# 51      74.266667            NaN
# 53      76.266667            NaN
# 54      77.620833            NaN
# 57      80.620833            NaN
# 58      80.634028            NaN
# ...           ...            ...
# 2698  3520.534954            NaN
# 2699  3520.561111            NaN
# 2700  3524.061111            NaN
# 2701  3525.061111            NaN
# 2702  3525.087269            NaN
# 2703  3528.587269            NaN
# 2704  3529.941435            NaN
# 2705  3531.941435            NaN
# 2706  3533.295602            NaN
# 2707  3536.295602            NaN
# 2708  3536.308796            NaN
# 2709  3542.308796            NaN
# 2710  3545.308796            NaN
# 2711  3545.335185            NaN
# 2712  3551.335185            NaN
# 2713  3554.335185            NaN
# 2714  3555.335185            NaN
# 2715  3555.361343            NaN
# 2716  3561.361343            NaN
# 2717  3562.361343            NaN
# 2718  3563.361343            NaN
# 2719  3563.387500            NaN
# 2720  3566.887500            NaN
# 2721  3567.887500            NaN
# 2722  3567.913657            NaN
# 2723  3571.413657            NaN
# 2724  3572.413657            NaN
# 2725  3572.439815            NaN
# 2726  3575.939815            NaN
# 2727  3577.293981            NaN
#
# [1493 rows x 15 columns]

# %% [markdown]
# ### Monopile design and installation

# %%
# Trip data
project._phases['MonopileInstallation'].wtiv.trip_data
# Out:
# [Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=7200, deck_space=3580.8, items={Monopile: 6, TransitionPiece: 6}),
#  Trip(cargo_weight=2400, deck_space=1193.6, items={Monopile: 2, TransitionPiece: 2})]

# %%
# Installation and capital costs 
mono_time = np.round(project._phases['MonopileInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
mono_install_cost = np.round(project._phases['MonopileInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
mono_capital_cost = np.round(((config['monopile']['weight'] * 
                     config['plant']['num_turbines'] * 
                     config['monopile']['monopile_steel_cost']) +
                     (config['transition_piece']['weight'] * 
                     config['plant']['num_turbines'] * 
                     config['transition_piece']['transition_piece_steel_cost']))* 1e-6 * usd_to_euro , 1)

print('Monopile install time: ', mono_time, 'days')
print('Monopile install cost: ', mono_install_cost, 'M Euros')
print('Monopile capital cost: ', mono_capital_cost, 'M Euros')
print('Monopile total cost: ', mono_capital_cost + mono_install_cost, 'M Euros')
# Out:
# Monopile install time:  87.4 days
# Monopile install cost:  23.3 M Euros
# Monopile capital cost:  120.0 M Euros
# Monopile total cost:  143.3 M Euros

# %%
proj_df = pd.DataFrame(project.project_actions)
proj_df.loc[proj_df['phase']=='MonopileInstallation']
# Out:
#                         action agent  cable_lay_speed           cost  \
# 0                     Mobilize  WTIV              NaN  752500.000000
# 6              Fasten Monopile  WTIV              NaN  107500.000000
# 14     Fasten Transition Piece  WTIV              NaN   71666.666667
# 23             Fasten Monopile  WTIV              NaN  107500.000000
# 28     Fasten Transition Piece  WTIV              NaN   71666.666667
# 37             Fasten Monopile  WTIV              NaN  107500.000000
# 42     Fasten Transition Piece  WTIV              NaN   71666.666667
# 49             Fasten Monopile  WTIV              NaN  107500.000000
# 55     Fasten Transition Piece  WTIV              NaN   71666.666667
# 65             Fasten Monopile  WTIV              NaN  107500.000000
# 72     Fasten Transition Piece  WTIV              NaN   71666.666667
# 81             Fasten Monopile  WTIV              NaN  107500.000000
# 89     Fasten Transition Piece  WTIV              NaN   71666.666667
# 99                     Transit  WTIV              NaN   74055.555556
# 100            Position Onsite  WTIV              NaN   17916.666667
# 101                     Jackup  WTIV              NaN   12131.076389
# 103                  RovSurvey  WTIV              NaN    8958.333333
# 106           Release Monopile  WTIV              NaN   26875.000000
# 107             Upend Monopile  WTIV              NaN     143.084491
# 108             Lower Monopile  WTIV              NaN       0.018001
# 109              Crane Reequip  WTIV              NaN    8958.333333
# 112             Drive Monopile  WTIV              NaN   13437.500000
# 115   Release Transition Piece  WTIV              NaN   17916.666667
# 116              Crane Reequip  WTIV              NaN    8958.333333
# 117                   Lower TP  WTIV              NaN      20.736883
# 119                    Bolt TP  WTIV              NaN   35833.333333
# 122                   Jackdown  WTIV              NaN   12131.076389
# 125            Position Onsite  WTIV              NaN   17916.666667
# 126                     Jackup  WTIV              NaN   12131.076389
# 128                  RovSurvey  WTIV              NaN    8958.333333
# ...                        ...   ...              ...            ...
# 2066   Fasten Transition Piece  WTIV              NaN   71666.666667
# 2070                   Transit  WTIV              NaN   74055.555556
# 2071           Position Onsite  WTIV              NaN   17916.666667
# 2074                    Jackup  WTIV              NaN   12131.076389
# 2075                 RovSurvey  WTIV              NaN    8958.333333
# 2076          Release Monopile  WTIV              NaN   26875.000000
# 2077                     Delay  WTIV              NaN   89583.333333
# 2078            Upend Monopile  WTIV              NaN     143.084491
# 2079            Lower Monopile  WTIV              NaN       0.018001
# 2080             Crane Reequip  WTIV              NaN    8958.333333
# 2082                     Delay  WTIV              NaN   17916.666667
# 2083            Drive Monopile  WTIV              NaN   13437.500000
# 2084  Release Transition Piece  WTIV              NaN   17916.666667
# 2085             Crane Reequip  WTIV              NaN    8958.333333
# 2086                  Lower TP  WTIV              NaN      20.736883
# 2089                   Bolt TP  WTIV              NaN   35833.333333
# 2092                  Jackdown  WTIV              NaN   12131.076389
# 2093           Position Onsite  WTIV              NaN   17916.666667
# 2094                    Jackup  WTIV              NaN   12131.076389
# 2095                 RovSurvey  WTIV              NaN    8958.333333
# 2098          Release Monopile  WTIV              NaN   26875.000000
# 2099            Upend Monopile  WTIV              NaN     143.084491
# 2100            Lower Monopile  WTIV              NaN       0.018001
# 2103             Crane Reequip  WTIV              NaN    8958.333333
# 2104            Drive Monopile  WTIV              NaN   13437.500000
# 2106  Release Transition Piece  WTIV              NaN   17916.666667
# 2109             Crane Reequip  WTIV              NaN    8958.333333
# 2110                  Lower TP  WTIV              NaN      20.736883
# 2114                   Bolt TP  WTIV              NaN   35833.333333
# 2115                  Jackdown  WTIV              NaN   12131.076389
#
#       cost_multiplier    duration  hub_height   level  max_waveheight  \
# 0                 0.5  168.000000         NaN  ACTION             NaN
# 6                 NaN   12.000000       113.0  ACTION             NaN
# 14                NaN    8.000000       113.0  ACTION             NaN
# 23                NaN   12.000000       113.0  ACTION             NaN
# 28                NaN    8.000000       113.0  ACTION             NaN
# 37                NaN   12.000000       113.0  ACTION             NaN
# 42                NaN    8.000000       113.0  ACTION             NaN
# 49                NaN   12.000000       113.0  ACTION             NaN
# 55                NaN    8.000000       113.0  ACTION             NaN
# 65                NaN   12.000000       113.0  ACTION             NaN
# 72                NaN    8.000000       113.0  ACTION             NaN
# 81                NaN   12.000000       113.0  ACTION             NaN
# 89                NaN    8.000000       113.0  ACTION             NaN
# 99                NaN    8.266667         NaN  ACTION             NaN
# 100               NaN    2.000000         NaN  ACTION             NaN
# 101               NaN    1.354167       113.0  ACTION             NaN
# 103               NaN    1.000000       113.0  ACTION             NaN
# 106               NaN    3.000000         NaN  ACTION             NaN
# 107               NaN    0.015972       113.0  ACTION             NaN
# 108               NaN    0.000002       113.0  ACTION             NaN
# 109               NaN    1.000000       113.0  ACTION             NaN
# 112               NaN    1.500000       113.0  ACTION             NaN
# 115               NaN    2.000000         NaN  ACTION             NaN
# 116               NaN    1.000000       113.0  ACTION             NaN
# 117               NaN    0.002315       113.0  ACTION             NaN
# 119               NaN    4.000000       113.0  ACTION             NaN
# 122               NaN    1.354167       113.0  ACTION             NaN
# 125               NaN    2.000000         NaN  ACTION             NaN
# 126               NaN    1.354167       113.0  ACTION             NaN
# 128               NaN    1.000000       113.0  ACTION             NaN
# ...               ...         ...         ...     ...             ...
# 2066              NaN    8.000000       113.0  ACTION             NaN
# 2070              NaN    8.266667         NaN  ACTION             NaN
# 2071              NaN    2.000000         NaN  ACTION             NaN
# 2074              NaN    1.354167       113.0  ACTION             NaN
# 2075              NaN    1.000000       113.0  ACTION             NaN
# 2076              NaN    3.000000         NaN  ACTION             NaN
# 2077              NaN   10.000000       113.0  ACTION             NaN
# 2078              NaN    0.015972       113.0  ACTION             NaN
# 2079              NaN    0.000002       113.0  ACTION             NaN
# 2080              NaN    1.000000       113.0  ACTION             NaN
# 2082              NaN    2.000000       113.0  ACTION             NaN
# 2083              NaN    1.500000       113.0  ACTION             NaN
# 2084              NaN    2.000000         NaN  ACTION             NaN
# 2085              NaN    1.000000       113.0  ACTION             NaN
# 2086              NaN    0.002315       113.0  ACTION             NaN
# 2089              NaN    4.000000       113.0  ACTION             NaN
# 2092              NaN    1.354167       113.0  ACTION             NaN
# 2093              NaN    2.000000         NaN  ACTION             NaN
# 2094              NaN    1.354167       113.0  ACTION             NaN
# 2095              NaN    1.000000       113.0  ACTION             NaN
# 2098              NaN    3.000000         NaN  ACTION             NaN
# 2099              NaN    0.015972       113.0  ACTION             NaN
# 2100              NaN    0.000002       113.0  ACTION             NaN
# 2103              NaN    1.000000       113.0  ACTION             NaN
# 2104              NaN    1.500000       113.0  ACTION             NaN
# 2106              NaN    2.000000         NaN  ACTION             NaN
# 2109              NaN    1.000000       113.0  ACTION             NaN
# 2110              NaN    0.002315       113.0  ACTION             NaN
# 2114              NaN    4.000000       113.0  ACTION             NaN
# 2115              NaN    1.354167       113.0  ACTION             NaN
#
#       max_windspeed                 phase            phase_name  site_depth  \
# 0               NaN  MonopileInstallation                   NaN         NaN
# 6               NaN  MonopileInstallation  MonopileInstallation        22.5
# 14              NaN  MonopileInstallation  MonopileInstallation        22.5
# 23              NaN  MonopileInstallation  MonopileInstallation        22.5
# 28              NaN  MonopileInstallation  MonopileInstallation        22.5
# 37              NaN  MonopileInstallation  MonopileInstallation        22.5
# 42              NaN  MonopileInstallation  MonopileInstallation        22.5
# 49              NaN  MonopileInstallation  MonopileInstallation        22.5
# 55              NaN  MonopileInstallation  MonopileInstallation        22.5
# 65              NaN  MonopileInstallation  MonopileInstallation        22.5
# 72              NaN  MonopileInstallation  MonopileInstallation        22.5
# 81              NaN  MonopileInstallation  MonopileInstallation        22.5
# 89              NaN  MonopileInstallation  MonopileInstallation        22.5
# 99              NaN  MonopileInstallation                   NaN         NaN
# 100             NaN  MonopileInstallation                   NaN         NaN
# 101             NaN  MonopileInstallation  MonopileInstallation        22.5
# 103             NaN  MonopileInstallation  MonopileInstallation        22.5
# 106             NaN  MonopileInstallation                   NaN         NaN
# 107             NaN  MonopileInstallation  MonopileInstallation        22.5
# 108             NaN  MonopileInstallation  MonopileInstallation        22.5
# 109             NaN  MonopileInstallation  MonopileInstallation        22.5
# 112             NaN  MonopileInstallation  MonopileInstallation        22.5
# 115             NaN  MonopileInstallation                   NaN         NaN
# 116             NaN  MonopileInstallation  MonopileInstallation        22.5
# 117             NaN  MonopileInstallation  MonopileInstallation        22.5
# 119             NaN  MonopileInstallation  MonopileInstallation        22.5
# 122             NaN  MonopileInstallation  MonopileInstallation        22.5
# 125             NaN  MonopileInstallation                   NaN         NaN
# 126             NaN  MonopileInstallation  MonopileInstallation        22.5
# 128             NaN  MonopileInstallation  MonopileInstallation        22.5
# ...             ...                   ...                   ...         ...
# 2066            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2070            NaN  MonopileInstallation                   NaN         NaN
# 2071            NaN  MonopileInstallation                   NaN         NaN
# 2074            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2075            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2076            NaN  MonopileInstallation                   NaN         NaN
# 2077            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2078            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2079            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2080            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2082            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2083            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2084            NaN  MonopileInstallation                   NaN         NaN
# 2085            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2086            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2089            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2092            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2093            NaN  MonopileInstallation                   NaN         NaN
# 2094            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2095            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2098            NaN  MonopileInstallation                   NaN         NaN
# 2099            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2100            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2103            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2104            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2106            NaN  MonopileInstallation                   NaN         NaN
# 2109            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2110            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2114            NaN  MonopileInstallation  MonopileInstallation        22.5
# 2115            NaN  MonopileInstallation  MonopileInstallation        22.5
#
#              time  transit_speed
# 0        0.000000            NaN
# 6       12.000000            NaN
# 14      20.000000            NaN
# 23      32.000000            NaN
# 28      40.000000            NaN
# 37      52.000000            NaN
# 42      60.000000            NaN
# 49      72.000000            NaN
# 55      80.000000            NaN
# 65      92.000000            NaN
# 72     100.000000            NaN
# 81     112.000000            NaN
# 89     120.000000            NaN
# 99     128.266667            NaN
# 100    130.266667            NaN
# 101    131.620833            NaN
# 103    132.620833            NaN
# 106    135.620833            NaN
# 107    135.636806            NaN
# 108    135.636808            NaN
# 109    136.636808            NaN
# 112    138.136808            NaN
# 115    140.136808            NaN
# 116    141.136808            NaN
# 117    141.139122            NaN
# 119    145.139122            NaN
# 122    146.493289            NaN
# 125    148.493289            NaN
# 126    149.847456            NaN
# 128    150.847456            NaN
# ...           ...            ...
# 2066  2041.144541            NaN
# 2070  2049.411208            NaN
# 2071  2051.411208            NaN
# 2074  2052.765374            NaN
# 2075  2053.765374            NaN
# 2076  2056.765374            NaN
# 2077  2066.765374            NaN
# 2078  2066.781346            NaN
# 2079  2066.781348            NaN
# 2080  2067.781348            NaN
# 2082  2069.781348            NaN
# 2083  2071.281348            NaN
# 2084  2073.281348            NaN
# 2085  2074.281348            NaN
# 2086  2074.283663            NaN
# 2089  2078.283663            NaN
# 2092  2079.637830            NaN
# 2093  2081.637830            NaN
# 2094  2082.991997            NaN
# 2095  2083.991997            NaN
# 2098  2086.991997            NaN
# 2099  2087.007969            NaN
# 2100  2087.007971            NaN
# 2103  2088.007971            NaN
# 2104  2089.507971            NaN
# 2106  2091.507971            NaN
# 2109  2092.507971            NaN
# 2110  2092.510286            NaN
# 2114  2096.510286            NaN
# 2115  2097.864452            NaN
#
# [775 rows x 15 columns]

# %% [markdown]
# ### Array cable design and installation

# %%
# Trip data
# project._phases['ArrayCableInstallation'].install_vessel.__dict__
# project._phases.keys()
# project._phases['ArraySystemDesign'].__dict__

project._phases['ArraySystemDesign'].detailed_output
# Out:
# {'length': {'XLPE_630mm_66kV': 84.5157749298},
#  'cost': {'XLPE_630mm_66kV': 34397920.3964286}}

# %%
# Installation and capital costs 
ac_time = np.round(project._phases['ArrayCableInstallation'].total_phase_time * (1/24) , 1) # Convert hours to days
ac_install_cost = np.round(project._phases['ArrayCableInstallation'].total_phase_cost * 1e-6 * usd_to_euro, 1)
ac_capital_cost = np.round(project._phases['ArraySystemDesign'].total_phase_cost * 1e-6 * usd_to_euro, 1)
total_length = np.round(project._phases['ArraySystemDesign'].detailed_output['length']['XLPE_630mm_66kV'], 1)

print('Array cable total length: ',total_length , 'km')
print('Array cable install time: ', ac_time, 'days')
print('Array cable install cost: ', ac_install_cost, 'M Euros')
print('Array cable capital cost: ', ac_capital_cost, 'M Euros')
print('Array cable total cost: ', ac_capital_cost + ac_install_cost, 'M Euros')
# Out:
# Array cable total length:  84.5 km
# Array cable install time:  69.6 days
# Array cable install cost:  13.3 M Euros
# Array cable capital cost:  31.6 M Euros
# Array cable total cost:  44.900000000000006 M Euros

# %%
# proj_df = pd.DataFrame(project.project_actions)
# proj_df.loc[(proj_df['phase']=='ArrayCableInstallation') ]
# Out:
#                action                            agent  cable_lay_speed  \
# 2            Mobilize  Array Cable Installation Vessel              NaN
# 4          Load Cable  Array Cable Installation Vessel              NaN
# 8             Transit  Array Cable Installation Vessel              NaN
# 10    Position Onsite  Array Cable Installation Vessel              NaN
# 12      Prepare Cable  Array Cable Installation Vessel              NaN
# 16      Pull In Cable  Array Cable Installation Vessel              NaN
# 18    Terminate Cable  Array Cable Installation Vessel              NaN
# 19        Lower Cable  Array Cable Installation Vessel              NaN
# 26     Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 27      Prepare Cable  Array Cable Installation Vessel              NaN
# 30      Pull In Cable  Array Cable Installation Vessel              NaN
# 34    Terminate Cable  Array Cable Installation Vessel              NaN
# 36    Position Onsite  Array Cable Installation Vessel              NaN
# 38      Prepare Cable  Array Cable Installation Vessel              NaN
# 41      Pull In Cable  Array Cable Installation Vessel              NaN
# 45    Terminate Cable  Array Cable Installation Vessel              NaN
# 46        Lower Cable  Array Cable Installation Vessel              NaN
# 50     Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 52      Prepare Cable  Array Cable Installation Vessel              NaN
# 56      Pull In Cable  Array Cable Installation Vessel              NaN
# 59    Terminate Cable  Array Cable Installation Vessel              NaN
# 61    Position Onsite  Array Cable Installation Vessel              NaN
# 62      Prepare Cable  Array Cable Installation Vessel              NaN
# 66      Pull In Cable  Array Cable Installation Vessel              NaN
# 71    Terminate Cable  Array Cable Installation Vessel              NaN
# 73        Lower Cable  Array Cable Installation Vessel              NaN
# 75     Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 77      Prepare Cable  Array Cable Installation Vessel              NaN
# 84      Pull In Cable  Array Cable Installation Vessel              NaN
# 88    Terminate Cable  Array Cable Installation Vessel              NaN
# ...               ...                              ...              ...
# 1651  Terminate Cable  Array Cable Installation Vessel              NaN
# 1653  Position Onsite  Array Cable Installation Vessel              NaN
# 1654    Prepare Cable  Array Cable Installation Vessel              NaN
# 1659    Pull In Cable  Array Cable Installation Vessel              NaN
# 1664  Terminate Cable  Array Cable Installation Vessel              NaN
# 1666      Lower Cable  Array Cable Installation Vessel              NaN
# 1670   Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 1673    Prepare Cable  Array Cable Installation Vessel              NaN
# 1675    Pull In Cable  Array Cable Installation Vessel              NaN
# 1679  Terminate Cable  Array Cable Installation Vessel              NaN
# 1680  Position Onsite  Array Cable Installation Vessel              NaN
# 1681    Prepare Cable  Array Cable Installation Vessel              NaN
# 1687    Pull In Cable  Array Cable Installation Vessel              NaN
# 1690  Terminate Cable  Array Cable Installation Vessel              NaN
# 1692      Lower Cable  Array Cable Installation Vessel              NaN
# 1698   Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 1699    Prepare Cable  Array Cable Installation Vessel              NaN
# 1704    Pull In Cable  Array Cable Installation Vessel              NaN
# 1710  Terminate Cable  Array Cable Installation Vessel              NaN
# 1711  Position Onsite  Array Cable Installation Vessel              NaN
# 1714    Prepare Cable  Array Cable Installation Vessel              NaN
# 1717    Pull In Cable  Array Cable Installation Vessel              NaN
# 1723  Terminate Cable  Array Cable Installation Vessel              NaN
# 1727      Lower Cable  Array Cable Installation Vessel              NaN
# 1737   Lay/Bury Cable  Array Cable Installation Vessel              0.2
# 1738    Prepare Cable  Array Cable Installation Vessel              NaN
# 1743    Pull In Cable  Array Cable Installation Vessel              NaN
# 1753  Terminate Cable  Array Cable Installation Vessel              NaN
# 1764          Transit  Array Cable Installation Vessel              NaN
# 1770          Transit  Array Cable Installation Vessel              NaN
#
#                cost  cost_multiplier    duration  hub_height   level  \
# 2     472500.000000              0.5  168.000000         NaN  ACTION
# 4      33750.000000              NaN    6.000000         NaN  ACTION
# 8      34875.000000              NaN    6.200000         NaN  ACTION
# 10     11250.000000              NaN    2.000000         NaN  ACTION
# 12      5625.000000              NaN    1.000000         NaN  ACTION
# 16     30937.500000              NaN    5.500000         NaN  ACTION
# 18     30937.500000              NaN    5.500000         NaN  ACTION
# 19      5625.000000              NaN    1.000000         NaN  ACTION
# 26     55454.633831              NaN    9.858602         NaN  ACTION
# 27      5625.000000              NaN    1.000000         NaN  ACTION
# 30     30937.500000              NaN    5.500000         NaN  ACTION
# 34     30937.500000              NaN    5.500000         NaN  ACTION
# 36     11250.000000              NaN    2.000000         NaN  ACTION
# 38      5625.000000              NaN    1.000000         NaN  ACTION
# 41     30937.500000              NaN    5.500000         NaN  ACTION
# 45     30937.500000              NaN    5.500000         NaN  ACTION
# 46      5625.000000              NaN    1.000000         NaN  ACTION
# 50     55454.633831              NaN    9.858602         NaN  ACTION
# 52      5625.000000              NaN    1.000000         NaN  ACTION
# 56     30937.500000              NaN    5.500000         NaN  ACTION
# 59     30937.500000              NaN    5.500000         NaN  ACTION
# 61     11250.000000              NaN    2.000000         NaN  ACTION
# 62      5625.000000              NaN    1.000000         NaN  ACTION
# 66     30937.500000              NaN    5.500000         NaN  ACTION
# 71     30937.500000              NaN    5.500000         NaN  ACTION
# 73      5625.000000              NaN    1.000000         NaN  ACTION
# 75     30375.000000              NaN    5.400000         NaN  ACTION
# 77      5625.000000              NaN    1.000000         NaN  ACTION
# 84     30937.500000              NaN    5.500000         NaN  ACTION
# 88     30937.500000              NaN    5.500000         NaN  ACTION
# ...             ...              ...         ...         ...     ...
# 1651   30937.500000              NaN    5.500000         NaN  ACTION
# 1653   11250.000000              NaN    2.000000         NaN  ACTION
# 1654    5625.000000              NaN    1.000000         NaN  ACTION
# 1659   30937.500000              NaN    5.500000         NaN  ACTION
# 1664   30937.500000              NaN    5.500000         NaN  ACTION
# 1666    5625.000000              NaN    1.000000         NaN  ACTION
# 1670   30375.000000              NaN    5.400000         NaN  ACTION
# 1673    5625.000000              NaN    1.000000         NaN  ACTION
# 1675   30937.500000              NaN    5.500000         NaN  ACTION
# 1679   30937.500000              NaN    5.500000         NaN  ACTION
# 1680   11250.000000              NaN    2.000000         NaN  ACTION
# 1681    5625.000000              NaN    1.000000         NaN  ACTION
# 1687   30937.500000              NaN    5.500000         NaN  ACTION
# 1690   30937.500000              NaN    5.500000         NaN  ACTION
# 1692    5625.000000              NaN    1.000000         NaN  ACTION
# 1698   38255.756136              NaN    6.801023         NaN  ACTION
# 1699    5625.000000              NaN    1.000000         NaN  ACTION
# 1704   30937.500000              NaN    5.500000         NaN  ACTION
# 1710   30937.500000              NaN    5.500000         NaN  ACTION
# 1711   11250.000000              NaN    2.000000         NaN  ACTION
# 1714    5625.000000              NaN    1.000000         NaN  ACTION
# 1717   30937.500000              NaN    5.500000         NaN  ACTION
# 1723   30937.500000              NaN    5.500000         NaN  ACTION
# 1727    5625.000000              NaN    1.000000         NaN  ACTION
# 1737   38255.756136              NaN    6.801023         NaN  ACTION
# 1738    5625.000000              NaN    1.000000         NaN  ACTION
# 1743   30937.500000              NaN    5.500000         NaN  ACTION
# 1753   30937.500000              NaN    5.500000         NaN  ACTION
# 1764   34875.000000              NaN    6.200000         NaN  ACTION
# 1770   34875.000000              NaN    6.200000         NaN  ACTION
#
#       max_waveheight  max_windspeed                   phase  \
# 2                NaN            NaN  ArrayCableInstallation
# 4                NaN            NaN  ArrayCableInstallation
# 8                NaN            NaN  ArrayCableInstallation
# 10               NaN            NaN  ArrayCableInstallation
# 12               NaN            NaN  ArrayCableInstallation
# 16               NaN            NaN  ArrayCableInstallation
# 18               NaN            NaN  ArrayCableInstallation
# 19               NaN            NaN  ArrayCableInstallation
# 26               2.0           25.0  ArrayCableInstallation
# 27               NaN            NaN  ArrayCableInstallation
# 30               NaN            NaN  ArrayCableInstallation
# 34               NaN            NaN  ArrayCableInstallation
# 36               NaN            NaN  ArrayCableInstallation
# 38               NaN            NaN  ArrayCableInstallation
# 41               NaN            NaN  ArrayCableInstallation
# 45               NaN            NaN  ArrayCableInstallation
# 46               NaN            NaN  ArrayCableInstallation
# 50               2.0           25.0  ArrayCableInstallation
# 52               NaN            NaN  ArrayCableInstallation
# 56               NaN            NaN  ArrayCableInstallation
# 59               NaN            NaN  ArrayCableInstallation
# 61               NaN            NaN  ArrayCableInstallation
# 62               NaN            NaN  ArrayCableInstallation
# 66               NaN            NaN  ArrayCableInstallation
# 71               NaN            NaN  ArrayCableInstallation
# 73               NaN            NaN  ArrayCableInstallation
# 75               2.0           25.0  ArrayCableInstallation
# 77               NaN            NaN  ArrayCableInstallation
# 84               NaN            NaN  ArrayCableInstallation
# 88               NaN            NaN  ArrayCableInstallation
# ...              ...            ...                     ...
# 1651             NaN            NaN  ArrayCableInstallation
# 1653             NaN            NaN  ArrayCableInstallation
# 1654             NaN            NaN  ArrayCableInstallation
# 1659             NaN            NaN  ArrayCableInstallation
# 1664             NaN            NaN  ArrayCableInstallation
# 1666             NaN            NaN  ArrayCableInstallation
# 1670             2.0           25.0  ArrayCableInstallation
# 1673             NaN            NaN  ArrayCableInstallation
# 1675             NaN            NaN  ArrayCableInstallation
# 1679             NaN            NaN  ArrayCableInstallation
# 1680             NaN            NaN  ArrayCableInstallation
# 1681             NaN            NaN  ArrayCableInstallation
# 1687             NaN            NaN  ArrayCableInstallation
# 1690             NaN            NaN  ArrayCableInstallation
# 1692             NaN            NaN  ArrayCableInstallation
# 1698             2.0           25.0  ArrayCableInstallation
# 1699             NaN            NaN  ArrayCableInstallation
# 1704             NaN            NaN  ArrayCableInstallation
# 1710             NaN            NaN  ArrayCableInstallation
# 1711             NaN            NaN  ArrayCableInstallation
# 1714             NaN            NaN  ArrayCableInstallation
# 1717             NaN            NaN  ArrayCableInstallation
# 1723             NaN            NaN  ArrayCableInstallation
# 1727             NaN            NaN  ArrayCableInstallation
# 1737             2.0           25.0  ArrayCableInstallation
# 1738             NaN            NaN  ArrayCableInstallation
# 1743             NaN            NaN  ArrayCableInstallation
# 1753             NaN            NaN  ArrayCableInstallation
# 1764             NaN            NaN  ArrayCableInstallation
# 1770             NaN            NaN  ArrayCableInstallation
#
#                   phase_name  site_depth         time  transit_speed
# 2                        NaN         NaN     0.000000            NaN
# 4     ArrayCableInstallation         NaN     6.000000            NaN
# 8     ArrayCableInstallation         NaN    12.200000            NaN
# 10                       NaN         NaN    14.200000            NaN
# 12    ArrayCableInstallation         NaN    15.200000            NaN
# 16    ArrayCableInstallation         NaN    20.700000            NaN
# 18    ArrayCableInstallation         NaN    26.200000            NaN
# 19    ArrayCableInstallation         NaN    27.200000            NaN
# 26    ArrayCableInstallation         NaN    37.058602           20.0
# 27    ArrayCableInstallation         NaN    38.058602            NaN
# 30    ArrayCableInstallation         NaN    43.558602            NaN
# 34    ArrayCableInstallation         NaN    49.058602            NaN
# 36                       NaN         NaN    51.058602            NaN
# 38    ArrayCableInstallation         NaN    52.058602            NaN
# 41    ArrayCableInstallation         NaN    57.558602            NaN
# 45    ArrayCableInstallation         NaN    63.058602            NaN
# 46    ArrayCableInstallation         NaN    64.058602            NaN
# 50    ArrayCableInstallation         NaN    73.917203           20.0
# 52    ArrayCableInstallation         NaN    74.917203            NaN
# 56    ArrayCableInstallation         NaN    80.417203            NaN
# 59    ArrayCableInstallation         NaN    85.917203            NaN
# 61                       NaN         NaN    87.917203            NaN
# 62    ArrayCableInstallation         NaN    88.917203            NaN
# 66    ArrayCableInstallation         NaN    94.417203            NaN
# 71    ArrayCableInstallation         NaN    99.917203            NaN
# 73    ArrayCableInstallation         NaN   100.917203            NaN
# 75    ArrayCableInstallation         NaN   106.317203           20.0
# 77    ArrayCableInstallation         NaN   107.317203            NaN
# 84    ArrayCableInstallation         NaN   112.817203            NaN
# 88    ArrayCableInstallation         NaN   118.317203            NaN
# ...                      ...         ...          ...            ...
# 1651  ArrayCableInstallation         NaN  1556.917203            NaN
# 1653                     NaN         NaN  1558.917203            NaN
# 1654  ArrayCableInstallation         NaN  1559.917203            NaN
# 1659  ArrayCableInstallation         NaN  1565.417203            NaN
# 1664  ArrayCableInstallation         NaN  1570.917203            NaN
# 1666  ArrayCableInstallation         NaN  1571.917203            NaN
# 1670  ArrayCableInstallation         NaN  1577.317203           20.0
# 1673  ArrayCableInstallation         NaN  1578.317203            NaN
# 1675  ArrayCableInstallation         NaN  1583.817203            NaN
# 1679  ArrayCableInstallation         NaN  1589.317203            NaN
# 1680                     NaN         NaN  1591.317203            NaN
# 1681  ArrayCableInstallation         NaN  1592.317203            NaN
# 1687  ArrayCableInstallation         NaN  1597.817203            NaN
# 1690  ArrayCableInstallation         NaN  1603.317203            NaN
# 1692  ArrayCableInstallation         NaN  1604.317203            NaN
# 1698  ArrayCableInstallation         NaN  1611.118226           20.0
# 1699  ArrayCableInstallation         NaN  1612.118226            NaN
# 1704  ArrayCableInstallation         NaN  1617.618226            NaN
# 1710  ArrayCableInstallation         NaN  1623.118226            NaN
# 1711                     NaN         NaN  1625.118226            NaN
# 1714  ArrayCableInstallation         NaN  1626.118226            NaN
# 1717  ArrayCableInstallation         NaN  1631.618226            NaN
# 1723  ArrayCableInstallation         NaN  1637.118226            NaN
# 1727  ArrayCableInstallation         NaN  1638.118226            NaN
# 1737  ArrayCableInstallation         NaN  1644.919250           20.0
# 1738  ArrayCableInstallation         NaN  1645.919250            NaN
# 1743  ArrayCableInstallation         NaN  1651.419250            NaN
# 1753  ArrayCableInstallation         NaN  1656.919250            NaN
# 1764  ArrayCableInstallation         NaN  1663.119250            NaN
# 1770  ArrayCableInstallation         NaN  1669.319250            NaN
#
# [460 rows x 15 columns]

# %% [markdown]
# ### Results - Old
#
# #### Array System Design

# %%
project._phases["ArraySystemDesign"].total_cable_length_by_type

# %%
project._phases['ArraySystemDesign'].num_full_strings

# %%
project._phases['ArraySystemDesign'].num_partial_strings

# %%
# Module outputs
project._phases['ArraySystemDesign'].total_phase_cost

# %%
total = sum([v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()])
print(f"Total length: {total}")

# %%
cables = project._phases['ArraySystemDesign'].cables

total_mass = sum([
    cables[k].linear_density*v for k, v in project._phases['ArraySystemDesign'].total_cable_length_by_type.items()
])
total_mass

# %% [markdown]
# #### Export System Design

# %%
project._phases['ExportSystemDesign'].total_mass

# %%
project._phases['ExportSystemDesign'].num_cables

# %%
project._phases['ExportSystemDesign'].cable.cable_power

# %%
project._phases['ExportSystemDesign']._plant_capacity

# %%
project._phases['ExportSystemDesign'].total_phase_cost * 2/3

# %%
project._phases['ExportSystemDesign'].total_length*2/3

# %% [markdown]
# #### Offshore Substation Design

# %%
project._phases["OffshoreSubstationDesign"].total_phase_cost

# %%
project._phases["OffshoreSubstationDesign"].design_result

# %% [markdown]
# #### Monopile Design

# %%
# config['monopile']['weight'] * config['plant']['num_turbines'] * 3000 <<<<------ OLD

# %%
project._phases["MonopileDesign"].total_phase_cost # <<<---- NEW

# %%
project._phases["MonopileDesign"].design_result

# %% [markdown]
# #### Scour Protection Design

# %%
project._phases['ScourProtectionDesign'].design_result  # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionDesign'].protection_depth

# %%
project._phases['ScourProtectionDesign'].total_phase_cost # <---- NEW

# %% [markdown]
# #### Monopile Installation

# %%
project._phases['MonopileInstallation'].total_phase_time / (8760 / 12)

# %%
project._phases['MonopileInstallation'].total_phase_cost

# %%
project._phases['MonopileInstallation'].detailed_output

# %%
project._phases['MonopileInstallation'].total_phase_time / 67

# %%
mi = project.project_dataframe.loc[project.project_dataframe['phase']=='MonopileInstallation']

mi.groupby('action').sum()['duration']

# %% [markdown]
# #### Scour Protection Installation

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / (8760 / 12) # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].total_phase_cost # <--- NEW, revised protection depth

# %%
project._phases['ScourProtectionInstallation'].detailed_output

# %%
project._phases['ScourProtectionInstallation'].total_phase_time / 67  # <--- NEW, revised protection depth

# %%
spi = project.project_dataframe.loc[project.project_dataframe['phase']=='ScourProtectionInstallation']

spi.groupby('action').sum()['duration']

# %% [markdown]
# #### Turbine Installation

# %%
project._phases['TurbineInstallation'].total_phase_time / (8760 / 12)  # NEW, turbine installation revised to eliminate too many crane reequips between blade installations

# %%
project._phases['TurbineInstallation'].total_phase_cost  # NEW, see above

# %%
project._phases['TurbineInstallation'].detailed_output

# %%
project._phases['TurbineInstallation'].total_phase_time / 67  # NEW, see above

# %%
ti = project.project_dataframe.loc[project.project_dataframe['phase']=='TurbineInstallation']

ti.groupby('action').sum()['duration']

# %%
project._phases['TurbineInstallation'].wtiv.trip_data

# %% [markdown]
# #### Array System Installation

# %%
project._phases['ArrayCableInstallation'].total_phase_time / (8760 / 12)  # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ArrayCableInstallation'].total_phase_cost

# %%
project._phases['ArrayCableInstallation'].detailed_output
# Out:
# {'Array Cable Installation Vessel': 0.9929244740664119}

# %%
asi = project.project_dataframe.loc[project.project_dataframe['phase']=='ArrayCableInstallation']

asi.groupby('action').sum()['duration']

# %% [markdown]
# #### Export System Installation

# %%
project._phases['ExportCableInstallation'].total_phase_time # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].total_phase_cost # NEW, not sure what changed but Rob should know. Burial rates?

# %%
project._phases['ExportCableInstallation'].detailed_output

# %%
esi = project.project_dataframe.loc[project.project_dataframe['phase']=='ExportCableInstallation']

esi.groupby('action').sum()['duration']

# %% [markdown]
# #### Offshore Substation Installation

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_time / (24)

# %%
project._phases['OffshoreSubstationInstallation'].total_phase_cost

# %%
project._phases['OffshoreSubstationInstallation'].detailed_output

# %%
osi = project.project_dataframe.loc[project.project_dataframe['phase']=='OffshoreSubstationInstallation']

osi.groupby('action').sum()['duration']

# %%
project.project_dataframe["phase"].unique()

# %%
project.design_results

# %%
project.project_dataframe.time.max() / (8760 / 12)

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_costs).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Cost ($USD)')

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

pd.Series(project.phase_times).plot(kind='bar', ax=axis)

axis.set_ylabel('Phase Time (h)')

# %%
phases = project.phase_dates.keys()
_start_dates = [project.phase_dates[p]['start'] for p in phases]
start_floats = [plt_dates.datestr2num(i) for i in _start_dates]
_end_dates = [project.phase_dates[p]['end'] for p in phases]
end_floats = [plt_dates.datestr2num(i) for i in _end_dates]

# %%
data = pd.DataFrame(columns=phases, data=[start_floats, end_floats], index=['Start', 'End']).T
data = data.reset_index().rename(columns={'index': 'Phase'})
data['Type'] = 'Model'

validation_data = data.copy()
validation_data = validation_data.set_index(keys='Phase')
validation_data.loc['MonopileInstallation', 'End'] = plt_dates.datestr2num("08/03/16 00:00")
validation_data.loc['ScourProtectionInstallation', 'End'] = plt_dates.datestr2num("09/30/16 00:00")
validation_data.loc['TurbineInstallation', 'End'] = plt_dates.datestr2num("09/04/17 00:00")
validation_data.loc['ArrayCableInstallation', 'End'] = plt_dates.datestr2num("08/27/16 00:00")
validation_data.loc['ExportCableInstallation', 'End'] = plt_dates.datestr2num("04/21/16 00:00")
validation_data['Type'] = 'Dudgeon'
validation_data = validation_data.reset_index().rename(columns={'index': 'Phase'})

data = pd.concat([data, validation_data])
data['Time'] = data['End'] - data['Start']
data

# %%
import seaborn as sns
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='Phase', y='Time', hue='Type', data=data, ax=axis)

for tick in axis.get_xticklabels():
    tick.set_rotation(90)
    
# axis.yaxis_date()
# fig.autofmt_xdate()

# %%
fig = plt.figure(figsize=(6, 4), dpi=200)
axis = fig.add_subplot(111)

axis = sns.barplot(x='End', y='Phase', data=data, ax=axis, zorder=3, hue='Type')
axis = sns.barplot(x='Start', y='Phase', data=data, ax=axis, palette={'Model': 'w', 'Dudgeon': 'w'}, zorder=5, hue='Type')

axis.set_xlim(data['Start'].min()-10, data['End'].max()+10)

# Legend
handles, labels = axis.get_legend_handles_labels()
axis.legend(handles[:2], labels[:2], fontsize=8)

# Formatting
axis.set_xlabel('')
# axis.grid(axis='x', which='major', lw=0.5, zorder=4)
# Tick parameters
axis.tick_params(axis='both', labelsize=8, width=0.5, length=3)

# Plot formatting
for ax in ['top', 'bottom', 'left', 'right']:
    axis.spines[ax].set_linewidth(0.5)
    axis.spines[ax].set_zorder(20)

axis.xaxis_date()
fig.autofmt_xdate()
